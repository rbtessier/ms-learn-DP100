# %% [markdown]
# # DP 100 Global Knowledge Class notes

# %% [markdown]
# # Introducing DP
# 1. Data Science Use Cases
# 2. Data Science Process
# 3. Data Science Deeper dive

# %% [markdown]
# ![image.png](attachment:a1c404ee-d924-4b4a-9502-c323c1003e82.png)

# %% [markdown]
# Translating business questions into questions that can be answered with Machine Learning. Takes a special skill in connecting all the dots in all the random data available to be a working data scientist. A person who connects the dots between the business world and the data world. Data science is the craft the data scientist uses to make this happen.
#
# Summary: process of Data Science is data munging, data mining, and creating actionable insights. Know python, R, Tableau, SQL and so on.
#
# R is statistically complete - any statistical product you have heard of has probably represented in R. Great for exploring data and running algorithms before writing complicated production ML code.
#
# Great tool for prototyping data science - identify key features and good enough machine learning before writing complicated production code for real. In addition, powerful visualization features, turn messy data mining into shiny report.
#
# Tableau is one of the best commercial software to explore data in this scenario. In addition very handy for creating interactive visualization or data stores.
#
# SQL also useful tool as a way to integrate different data sources and is great for data exploration and debugging.

# %% [markdown]
# ![image.png](attachment:264be5fb-c025-4019-95bc-23fa9548da22.png)

# %% [markdown]
# Data Storytelling is an underrated skill - its not at all enough to be technically skilled without having the ability to explain and tell a story about the data.
#
# Without Data storytelling its hard
#
# ![image.png](attachment:711aa3da-301a-483c-a5d3-64f359464e62.png)

# %% [markdown]
# VP of sales, need to walk them through each step on the chart here to show how this plays out in practice. This is not a theoreteical scenario, this is exactly what you will do in the field. Business Understanding is **ASKING THE RIGHT QUESTIONS**. Uses this case study as an example.
#
# ie. say you want to improve conversion rates, ask questions, meaningful questions. Who are the customers, what is the sales process, what kind of information do you collect about customers, what are the different tiers of service. Get into your clients head and understand their view of the problem as well as you can. This knowledge will be invaluable when you analyze your data and present the insights within. Once have a reasonable grasp of the domain, ask more pointed questions - what does optimizing funnel look like? (ie. Carlo had client in 2005, kept talking about project managers, but after asking questions realized they were all account managers instead of project managers.)
#
# What are some important customer segments?
# How do conversion rates vary?
# Do some segments perform better?
# HOw precdicct conversion?
# Identify customers on the fence?
# Return on investment on marketing spending?
#
# Once some concrete questions, you go back to VP sales, and they will add some. VP may add, how likely customer is to convert. Then identify data available to identify customers on the fence.
#
# Backend for CRM Convenient web based app returns in JSON format. What data from CRM database do you need, and how should you extract it in this format. What form should we store in.
#
# Roll up sleeves and dive into the SQL Database. all info in SQL database -
#
# Select and Cleanse data
#
# Trying ot help vp of sales extracted data into CSV files. Despite work, not ready to use data yet. First have to make sure data is CLEAN. Data clearning and wrangling takes up bulk of time in data scientist day to day work. Requires patience and focus. You're not going to like it if you're not patient.
#
# 1. First need to look through and udnerstand what all columns mean.
#   - missing values
#   - customers without contact date good or bad?
#   - time zone?
#   - do all entries represent same time zone?
#   - Is date range valid?
#   - Dates before that date?
#   - Dates before 2010?
#   - verify details with sales team.
# 2. After uncovering missing or corect values, what do you do with them - sometimes throw away, sometimes include reasonable default values. As data scientist, decide which makes sense for your specific problem. Have to repeat steps for every field in CSV file.
#
# After cleaning, do exploratory data analysis. Find out information data contains, then start exploring. May have spent days and weeks to aimlessly plot away, becasue knowing what to explore takes a lot of thinking. If you don't have much time, and need to see and present results at a meeting or help VP take to her meeting, your might go back to the original question. So perhaps split data into 2 segments, converts or not. Start noticing some patterns: when you plot on histogram might see people in their 30s buy, but 20s don't buy. Get first benefits of data science. May find many customers who convert were targeted due to email and not social media. Do statistical test using inferential statistics.
#
# Question: how do you come up with the feature vectors? Identified factors that might be important (age (numeric), marketing method (catyegorical) email vs social media)
#
# Know how to correctly convert numeric or categorical to features. You also need labels. For this, use the converted field as a boolean field. 1 indicates customer converted, 0 they didnt' convert. Now that we have features and labels use simple ML classifier. (Carlo will show us what they'r eworking on in Microsoft)
#
# This is contrary to unsupervised learning - no labels
#
# So many people are bad at communicating the message. While Engineers can get away with being siloed, data scientist must be an effective communicator - set of skills is Data Storytelling. What kind of story can you tell based on the work you've done so far, will contain important conclusions based on predictive analytics phase.
#
# Unexpected result in case study, we're selling more to 30 year olds despite targeting 20 year old people. Target social media to 20s and email to 30s - significant factor in conversion rate. But then, she may ask something, how can we best use findings... Still within Data Scientist job description. Role as data scientist is thne interpreter of data.
#
# ![image.png](attachment:2734b9fa-1c1f-4cb7-8e8c-fee5b9e6875a.png)

# %% [markdown]
# ![image.png](attachment:25c56243-65aa-4012-845e-1a3e8c539bb3.png)

# %% [markdown]
# Working with health data is mindbogging and its a nightmare to work through.
#
# ![image.png](attachment:ebc3965a-36a4-4751-af2c-c47b1b919be0.png)

# %% [markdown]
# Feature engineering has a process
# 1. Brainstorming or testing features
# 2. Deciding what to create
# 3. Creating features
# 4. Testing
#
# Loop through a process like this. Deep Feature synthesis algorithm by MIT called feature tools can be very helpful for feature engineering.

# %% [markdown]
# ![image.png](attachment:318622e9-13a5-4fdc-a7f5-c8bb70c861f0.png)

# %% [markdown]
# ![image.png](attachment:0329b4d9-bae7-4429-8d73-b91a8e08341b.png)

# %% [markdown]
# Key technology behind driverless cars also to voice control and consumer devices. Computer model learns classification text from images, text or sound. Sometimes they can achieve better than human levels of predictions. How does it obtain such impressive results - 1 word: accuracy!
#
# Achieves recognition accuracy more than ever before. Crucial for safety critical applications like driverless cars. In recent advances in deep learning, some tasks like classifying objects and images. Deep learning first theorize in early 1980s but no one focused on it.
#
# Deep learning requires a large amount of data and substantial computing power, which is why its only now becoming well used.
#
# millions of images and thousands of hour sof video. All have a parallel architecture that is efficient for deep learning. When combined with cloud systems and cloud clusters, training time has been reduced from weeks to hours to minutes. Imagine being a government agency with 18 acres of virtualized servers. Imagine if microsoft azure with centers in existence in 140 regions around th eearth all connected within private line with your own undersea cables, imagine the power you have. This is why we can do stuff in literally no time at all.
#
# Deep learning applications used in industries such as automative, used to detect pedestrians as well. In aerospace locate areas of interest - US northern command and norad, also in canadian forces, in peterson airforce base in colorado we have an entire section that used deep learning. Used to identify missiles and nuclear weapons all using deep learning. Focused on medical research: cancer reserachers using deep learning ot automatically detect cancer cells. High dimensional dataset to accurately identify cancer cells. Industrial automation as well. Used to detect worker safety with heavy machinery and avoid accidents. Electronics also used, used in automated engineering, automated speech translation. Home assistance devices are all powered by deep learning applications. '

# %% [markdown]
# ![image.png](attachment:d6e233a3-cde2-4835-b399-1bc4bfe3019d.png)

# %% [markdown]
# ![image.png](attachment:2bff09ba-0ae1-4814-a21f-a911630a8537.png)

# %% [markdown]
# Classification and regression are still a majority of the situations in machine learning.

# %% [markdown]
# ![image.png](attachment:ec4723bc-2a91-47fd-a198-d3f870dcfe87.png)

# %% [markdown]
# ![image.png](attachment:3c15f790-8e24-4bc3-af39-abc54c51ef83.png)

# %% [markdown]
# One of the most time consuming pieces, often have to rewrite to be compatible with existing systems. This is useful in order to use the model it need to be effectively deployed into production. Without practical insights, model is wasted. Imagine using a big chunk of life and come up with a model that is very limited. In order to get the most value, its important ot deployment as effectively as possible so that it can be used for

# %% [markdown]
# ![image.png](attachment:6b75d883-6e70-4518-b13c-ed7ad6cbfc11.png)

# %% [markdown]
# Data scientist is rare in this world, closer you get to silicon valley the more valuable the title becomes. Data Architect - important is rapidly increasing - by federal law the role is required. The person in this role create the blueprint for data management systems. Data architect background in software engineering and loves playing around with database systems, easily master technology and statistical programming. With dawn of cloud and sharepoint, web programming should be a critical component of this. Data engineer should be
#
# Historical leader of data is the Statistician - do not underestimate or undermine this position. This position has been forgotten and replaced by a lot of organizations. People don't think a lot of them but they are SO mistaken. They represent what the field stands for... getting useful insights from data. Should have strong background in stats. Should be able to harvest data and and can handle all sorts. Thanks to quant background able to quickly master new technologies and use these to boost their intellectual capacity. They bring the magic to the table to radically transform businesses today. Also database administrator - you need someone who exploits the valueable data mine. Make sure database is available to all relevant users. Think about how to avoid disasters come to database admin. Ensure all systems and security is in place. Keep track of different technologies and how to support these technologies. We've all studied and seen this, very important position or title is the business analyst. A bit different from rest of the team - less technically oriented, but makes up for it by deep knowledge of different business processes. Links data insights to business insights, spread message across organization with this. Acts as intermediary as business guys and techies. Many companies looking for these people.
#
# Usually see companies like Uber, Dell etc hiring business analysts. Data and analytics manager steers direction of the data science team and ensures the right priorities are set. Combines strong technical skills with the social skills required to manage a team. Its a hard job, but somethign to keep in mind is that they're highly in demand and companies are hiring lots of those positions or need analytics managers. Coursera, motorola or slack.

# %% [markdown]
# ![image.png](attachment:e38841e5-792b-4b44-bdca-6de9584f6b74.png)

# %% [markdown]
# ![image.png](attachment:60c22d7d-0ed9-422e-82bc-81f71561bb5c.png)

# %% [markdown]
# ![image.png](attachment:45aedb98-da60-4b5f-87f5-f0b44df54ee9.png)
#
# Spark allows in-memory processing, loaded into RAM. Spark integrates into the Scala programming language.
#
# Everything you need in spark can be used in Azure.
#
# ![image.png](attachment:2f67138e-662d-4df4-b5c0-1889c7b853d3.png)

# %% [markdown]
# Databricks is something that is offered as an integrated Azure service - if you want a cloud service (initially built by team who started spark).
#
# Fast easy to use spark based platform. If you decide to use memory based computing here it is. Single platform for big da
# ![image.png](attachment:c5e4fd5f-836e-406e-b6a0-114cf7c9ac03.png)

# %% [markdown]
# ![image.png](attachment:bd4c5e1c-abf8-4005-b388-e97fcfd1a239.png)

# %% [markdown]
# Serverless clusters exist and can share across teams - serverless means you just don't have to worry about servers

# %% [markdown]
# ![image.png](attachment:20761d5f-082e-4f92-ac2e-17f94ae30163.png)

# %% [markdown]
# ![image.png](attachment:62fc95f4-f140-401a-91cf-f3df7e17fbbe.png)
