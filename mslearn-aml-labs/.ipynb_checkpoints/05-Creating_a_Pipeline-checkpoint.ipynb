# %% [markdown]
# # Creating an Azure Machine Learning Pipeline
#
# You can perform the various steps required to ingest data, train a model, and register the model individually by using the Azure ML SDK to run script-based experiments. However, in an enterprise environment it is common to encapsulate the sequence of discrete steps required to build a machine learning solution into a *pipeline* that can be run on one or more compute targets, either on-demand by a user, from an automated build process, or on a schedule.
#
# In this lab, you'll bring together all of these elements to create a simple pipeline that trains and registers a model.
#
# ## Connect to Your Workspace
#
# The first thing you need to do is to connect to your workspace using the Azure ML SDK.
#
# > **Note**: If the authenticated session with your Azure subscription has expired since you completed the previous exercise, you'll be prompted to reauthenticate.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Performing interactive authentication. Please follow the instructions on the terminal.
# WARNING - Note, we have launched a browser for you to login. For old experience with device code, use "az login --use-device-code"
# WARNING - You have logged in. Now let us find all the subscriptions to which you have access...
# Interactive authentication successfully completed.
# Ready to use Azure ML 1.9.0 to work with ms-learn-ml

# %% [markdown]
# ## Prepare the Training Data
#
# You can use local data files to train a model, but when running training workloads automatically on cloud-based compute, it makes more sense to store the data centrally in the cloud and ingest it into the training script wherever it happens to be running.
#
# In this lab, you'll upload the training data to a *datastore* and define a *dataset* that can be used to access the data from a training script. For simplicity, you'll upload the data to the default datastore for your Azure Machine Learning workspace - this is an Azure Storage blob container that was created when you provisioned the workspace. In a real solution, you'd likely register a datastore that references the cloud location where you typically store your data. You'll then create a *tabular* dataset that references the CSV files you uploaded.

# %%
from azureml.core import Dataset

default_ds = ws.get_default_datastore()

if 'diabetes dataset' not in ws.datasets:
    default_ds.upload_files(files=[r'C:\Users\psych\Jupyter Projects\ms-learn-DP100\mslearn-aml-labs\data\diabetes.csv', r'C:\Users\psych\Jupyter Projects\ms-learn-DP100\mslearn-aml-labs\data\diabetes2.csv'], # Upload the diabetes csv files in /data
                        target_path='diabetes-data/', # Put it in a folder path in the datastore
                        overwrite=True, # Replace existing files of the same name
                        show_progress=True)

    #Create a tabular dataset from the path on the datastore (this may take a short while)
    tab_data_set = Dataset.Tabular.from_delimited_files(path=(default_ds, 'diabetes-data/*.csv'))

    # Register the tabular dataset
    try:
        tab_data_set = tab_data_set.register(workspace=ws, 
                                name='diabetes dataset',
                                description='diabetes data',
                                tags = {'format':'CSV'},
                                create_new_version=True)
        print('Dataset registered.')
    except Exception as ex:
        print(ex)
else:
    print('Dataset already registered.')
# Out:
# Uploading an estimated of 2 files
# Uploading C:\Users\psych\Jupyter Projects\ms-learn-DP100\mslearn-aml-labs\data\diabetes.csv
# Uploading C:\Users\psych\Jupyter Projects\ms-learn-DP100\mslearn-aml-labs\data\diabetes2.csv
# Uploaded C:\Users\psych\Jupyter Projects\ms-learn-DP100\mslearn-aml-labs\data\diabetes2.csv, 1 files out of an estimated total of 2
# Uploaded C:\Users\psych\Jupyter Projects\ms-learn-DP100\mslearn-aml-labs\data\diabetes.csv, 2 files out of an estimated total of 2
# Uploaded 2 files
# Dataset registered.

# %% [markdown]
# ## Create Scripts for Pipeline Steps
#
# Now you're ready to start work on your pipeline. Pipelines consist of one or more *steps*, which can be Python scripts, or specialized steps like an Auto ML training estimator or a data transfer step that copies data from one location to another. Each step can run in its own compute context.
#
# In this exercise, you'll build a simple pipeline that contains an estimator step (to train a model) and a Python script step (to register the trained model). Start by creating a folder to contain the scripts for each step.

# %%
import os
# Create a folder for the pipeline step files
experiment_folder = 'diabetes_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# diabetes_pipeline

# %% [markdown]
# The first step will use an estimator to run a training script. The code in the following cell creates this script for you. Note that the script includes a parameter named **output_folder**, which references the folder where the trained model should be saved.

# %%
# %%writefile $experiment_folder/train_diabetes.py
# Import libraries
from azureml.core import Run
import argparse
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument('--output_folder', type=str, dest='output_folder', default="diabetes_model", help='output folder')
args = parser.parse_args()
output_folder = args.output_folder

# Get the experiment run context
run = Run.get_context()

# load the diabetes data (passed as an input dataset)
print("Loading Data...")
diabetes = run.input_datasets['diabetes_train'].to_pandas_dataframe()

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train adecision tree model
print('Training a decision tree model')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# Save the trained model
os.makedirs(output_folder, exist_ok=True)
output_path = output_folder + "/model.pkl"
joblib.dump(value=model, filename=output_path)

run.complete()
# Out:
# Writing diabetes_pipeline/train_diabetes.py

# %% [markdown]
# The script for the second step of the pipeline will load the model from where it was saved, and then register it in the workspace. It includes a single **model_folder** parameter that contains the path to the folder where the model was saved by the previous step.

# %%
# %%writefile $experiment_folder/register_diabetes.py
# Import libraries
import argparse
import joblib
from azureml.core import Workspace, Model, Run

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument('--model_folder', type=str, dest='model_folder', default="diabetes_model", help='model location')
args = parser.parse_args()
model_folder = args.model_folder

# Get the experiment run context
run = Run.get_context()

# load the model
print("Loading model from " + model_folder)
model_file = model_folder + "/model.pkl"
model = joblib.load(model_file)

Model.register(workspace=run.experiment.workspace,
               model_path = model_file,
               model_name = 'diabetes_model',
               tags={'Training context':'Pipeline'})

run.complete()
# Out:
# Writing diabetes_pipeline/register_diabetes.py

# %% [markdown]
# ## Prepare a Compute Environment for the Pipeline Steps
#
# The pipeline will eventually be published and run on-demand, so it needs a compute environment in which to run. In this exercise, you'll use the same compute for both steps, but it's important to realize that each step is run independently; so you could specify different compute contexts for each step if appropriate.
#
# First, you need a compute target. In this case, you create an Azure Machine Learning compute cluster in your workspace (or use an existing one if you have created it previously).
#
# > **Important**: Change *your-compute-cluster* to the unique name for your compute cluster in the code below before running it!

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "ms-learn-CCryan"

# Verify that cluster exists
try:
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If not, create it
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',
                                                           max_nodes=4,
                                                           idle_seconds_before_scaledown=1800)
    pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)

pipeline_cluster.wait_for_completion(show_output=True)
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# The compute will require a Python environment with the necessary package dependencies installed, so we'll create a run configuration.

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import RunConfiguration

# Create a Python environment for the experiment
diabetes_env = Environment("diabetes-pipeline-env")
diabetes_env.python.user_managed_dependencies = False # Let Azure ML manage dependencies
diabetes_env.docker.enabled = True # Use a docker container

# Create a set of package dependencies
diabetes_packages = CondaDependencies.create(conda_packages=['scikit-learn','pandas'],
                                             pip_packages=['azureml-defaults','azureml-dataprep[pandas]'])

# Add the dependencies to the environment
diabetes_env.python.conda_dependencies = diabetes_packages

# Register the environment (just in case you want to use it again)
diabetes_env.register(workspace=ws)
registered_env = Environment.get(ws, 'diabetes-pipeline-env')

# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Use the compute you created above. 
pipeline_run_config.target = pipeline_cluster

# Assign the environment to the run configuration
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# Run configuration created.

# %% [markdown]
# ## Create and Run a Pipeline
#
# Now you're ready to define and run the pipeline.
#
# First you need to define the steps for the pipeline, and any data references that need to passed between them. In this case, the first step must write the model to a folder that can be read from by the second step. Since the steps will be run on remote compute (and in fact, could each be run on different compute), the folder path must be passed as a data reference to a location in a datastore within the workspace. The **PipelineData** object is a special kind of data reference that is used to pass data from the output of one pipeline step to the input of another, creating a dependency between them. You'll create one and use it as the output for the first step and the input for the second step. Note that you also need to pass it as a script argument so your code can access the datastore location referenced by the data reference.

# %%
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep, EstimatorStep
from azureml.train.estimator import Estimator

# Get the training dataset
diabetes_ds = ws.datasets.get("diabetes dataset")

# Create a PipelineData (temporary Data Reference) for the model folder
model_folder = PipelineData("model_folder", datastore=ws.get_default_datastore())

estimator = Estimator(source_directory=experiment_folder,
                        compute_target = pipeline_cluster,
                        environment_definition=pipeline_run_config.environment,
                        entry_script='train_diabetes.py')

# Step 1, run the estimator to train the model
train_step = EstimatorStep(name = "Train Model",
                           estimator=estimator, 
                           estimator_entry_script_arguments=['--output_folder', model_folder],
                           inputs=[diabetes_ds.as_named_input('diabetes_train')],
                           outputs=[model_folder],
                           compute_target = pipeline_cluster,
                           allow_reuse = True)

# Step 2, run the model registration script
register_step = PythonScriptStep(name = "Register Model",
                                source_directory = experiment_folder,
                                script_name = "register_diabetes.py",
                                arguments = ['--model_folder', model_folder],
                                inputs=[model_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

print("Pipeline steps defined")
# Out:
# Pipeline steps defined

# %% [markdown]
# OK, now you're ready to build the pipeline from the steps you've defined and run it as an experiment.
#
# > **Note**: This may take a while. The training cluster must be started and configured with the Python environment before the scripts can be run. Now might be a good time to take a coffee break!

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline
#from azureml.widgets import RunDetails

# Construct the pipeline
pipeline_steps = [train_step, register_step]
pipeline = Pipeline(workspace = ws, steps=pipeline_steps)
print("Pipeline is built.")

# Create an experiment and run the pipeline
experiment = Experiment(workspace = ws, name = 'diabetes-training-pipeline')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print("Pipeline submitted for execution.")

#RunDetails(pipeline_run).show()
pipeline_run.wait_for_completion()
# Out:
# Pipeline is built.
# Created step Train Model [aa7c315a][6637b894-0c90-4b60-b102-5c0714ffd674], (This step will run and generate new outputs)Created step Register Model [3d0a4f50][9e6e1e5b-746b-4681-977a-74c448980ea7], (This step will run and generate new outputs)
#
# Submitted PipelineRun 0ea01d5e-0f18-4409-8fa2-71bd5f36899f
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/0ea01d5e-0f18-4409-8fa2-71bd5f36899f?wsid=/subscriptions/375be063-544d-4b99-aed9-5a0e16b1f428/resourcegroups/ms-learn-ml/workspaces/ms-learn-ml
# Pipeline submitted for execution.
# PipelineRunId: 0ea01d5e-0f18-4409-8fa2-71bd5f36899f
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/0ea01d5e-0f18-4409-8fa2-71bd5f36899f?wsid=/subscriptions/375be063-544d-4b99-aed9-5a0e16b1f428/resourcegroups/ms-learn-ml/workspaces/ms-learn-ml
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 57b7206e-d68d-451b-8ccb-896341ad878f
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/57b7206e-d68d-451b-8ccb-896341ad878f?wsid=/subscriptions/375be063-544d-4b99-aed9-5a0e16b1f428/resourcegroups/ms-learn-ml/workspaces/ms-learn-ml
# StepRun( Train Model ) Status: NotStarted
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# StepRun( Train Model ) Status: Running
# 2020/08/15 16:07:19 Downloading source code...
# 2020/08/15 16:07:20 Finished downloading source code
# 2020/08/15 16:07:21 Creating Docker network: acb_default_network, driver: 'bridge'
# 2020/08/15 16:07:21 Successfully set up Docker network: acb_default_network
# 2020/08/15 16:07:21 Setting up Docker configuration...
# 2020/08/15 16:07:22 Successfully set up Docker configuration
# 2020/08/15 16:07:22 Logging in to registry: b1533106f06a49c8a9a7078ce1e0e1a3.azurecr.io
# 2020/08/15 16:07:23 Successfully logged into b1533106f06a49c8a9a7078ce1e0e1a3.azurecr.io
# 2020/08/15 16:07:23 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/08/15 16:07:23 Scanning for dependencies...
# 2020/08/15 16:07:24 Successfully scanned dependencies
# 2020/08/15 16:07:24 Launching container with name: acb_step_0
# Sending build context to Docker daemon  60.93kB
#
# Step 1/15 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200423.v1@sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d
# sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# fe703b657a32: Pulling fs layer
# f9df1fafd224: Pulling fs layer
# a645a4b887f9: Pulling fs layer
# 57db7fe0b522: Pulling fs layer
# 20b5fabe4f63: Pulling fs layer
# 22898513a7dc: Pulling fs layer
# b77f65fcd9d7: Pulling fs layer
# 132ebd5cd5ca: Pulling fs layer
# 01991399be72: Pulling fs layer
# 60c58ca14ef7: Pulling fs layer
# ca339bb1ce1b: Pulling fs layer
# b77f65fcd9d7: Waiting
# 132ebd5cd5ca: Waiting
# 01991399be72: Waiting
# 57db7fe0b522: Waiting
# 20b5fabe4f63: Waiting
# 22898513a7dc: Waiting
# 60c58ca14ef7: Waiting
# ca339bb1ce1b: Waiting
# a645a4b887f9: Verifying Checksum
# a645a4b887f9: Download complete
# f9df1fafd224: Verifying Checksum
# f9df1fafd224: Download complete
# 57db7fe0b522: Verifying Checksum
# 57db7fe0b522: Download complete
# fe703b657a32: Verifying Checksum
# fe703b657a32: Download complete
# 22898513a7dc: Verifying Checksum
# 22898513a7dc: Download complete
# b77f65fcd9d7: Verifying Checksum
# b77f65fcd9d7: Download complete
# 20b5fabe4f63: Verifying Checksum
# 20b5fabe4f63: Download complete
# fe703b657a32: Pull complete
# f9df1fafd224: Pull complete
# a645a4b887f9: Pull complete
# 57db7fe0b522: Pull complete
# 60c58ca14ef7: Verifying Checksum
# 60c58ca14ef7: Download complete
# ca339bb1ce1b: Verifying Checksum
# ca339bb1ce1b: Download complete
# 132ebd5cd5ca: Verifying Checksum
# 132ebd5cd5ca: Download complete
# 01991399be72: Verifying Checksum
# 01991399be72: Download complete
# 20b5fabe4f63: Pull complete
# 22898513a7dc: Pull complete
# b77f65fcd9d7: Pull complete
# 132ebd5cd5ca: Pull complete
# 01991399be72: Pull complete
# 60c58ca14ef7: Pull complete
# ca339bb1ce1b: Pull complete
# Digest: sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200423.v1@sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d
#  ---> a0dab4f7c804
# Step 2/15 : USER root
#  ---> Running in 7c8f87ba31ff
# Removing intermediate container 7c8f87ba31ff
#  ---> 3c282d8e080f
# Step 3/15 : RUN mkdir -p $HOME/.cache
#  ---> Running in a04efca9a069
# Removing intermediate container a04efca9a069
#  ---> 16ddf7b6a3ff
# Step 4/15 : WORKDIR /
#  ---> Running in 677dc0a3da9e
# Removing intermediate container 677dc0a3da9e
#  ---> 85a24bdbc645
# Step 5/15 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> b43c6b3720b0
# Step 6/15 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in e6049f2e997a
# Removing intermediate container e6049f2e997a
#  ---> 65b2968193a2
# Step 7/15 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> a8d461f9f38f
# Step 8/15 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_011719923a2b78fea7f361db3a50870b -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 5c45cdfc941c
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# ca-certificates-2020 | 133 KB    |            |   0%
# ca-certificates-2020 | 133 KB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# setuptools-49.6.0    | 927 KB    |            |   0%
# setuptools-49.6.0    | 927 KB    | ########## | 100%
#
# mkl_fft-1.1.0        | 159 KB    |            |   0%
# mkl_fft-1.1.0        | 159 KB    | ########## | 100%
#
# scikit-learn-0.23.1  | 6.9 MB    |            |   0%
# scikit-learn-0.23.1  | 6.9 MB    | #########7 |  98%
# scikit-learn-0.23.1  | 6.9 MB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# pip-20.2.2           | 2.0 MB    |            |   0%
# pip-20.2.2           | 2.0 MB    | ########## | 100%
#
# wheel-0.34.2         | 49 KB     |            |   0%
# wheel-0.34.2         | 49 KB     | ###2       |  33%
# wheel-0.34.2         | 49 KB     | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# pandas-1.1.0         | 10.5 MB   |            |   0%
# pandas-1.1.0         | 10.5 MB   | ####2      |  42%
# pandas-1.1.0         | 10.5 MB   | ########## | 100%
#
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# joblib-0.16.0        | 210 KB    |            |   0%
# joblib-0.16.0        | 210 KB    | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | ########   |  81%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# intel-openmp-2020.1  | 940 KB    |            |   0%
# intel-openmp-2020.1  | 940 KB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# scipy-1.5.0          | 18.6 MB   |            |   0%
# scipy-1.5.0          | 18.6 MB   | ###6       |  36%
# scipy-1.5.0          | 18.6 MB   | ########7  |  87%
# scipy-1.5.0          | 18.6 MB   | ########## | 100%
#
# pytz-2020.1          | 239 KB    |            |   0%
# pytz-2020.1          | 239 KB    | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ##5        |  26%
# python-3.6.2         | 27.0 MB   | ######1    |  61%
# python-3.6.2         | 27.0 MB   | #########6 |  97%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# libffi-3.2.1         | 43 KB     |            |   0%
# libffi-3.2.1         | 43 KB     | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 3          |   3%
# mkl-2019.4           | 204.1 MB  | 7          |   8%
# mkl-2019.4           | 204.1 MB  | #1         |  12%
# mkl-2019.4           | 204.1 MB  | #6         |  17%
# mkl-2019.4           | 204.1 MB  | ##1        |  21%
# mkl-2019.4           | 204.1 MB  | ##6        |  26%
# mkl-2019.4           | 204.1 MB  | ###        |  31%
# mkl-2019.4           | 204.1 MB  | ###5       |  35%
# mkl-2019.4           | 204.1 MB  | ####       |  40%
# mkl-2019.4           | 204.1 MB  | ####4      |  45%
# mkl-2019.4           | 204.1 MB  | ####8      |  49%
# mkl-2019.4           | 204.1 MB  | #####3     |  53%
# mkl-2019.4           | 204.1 MB  | #####8     |  58%
# mkl-2019.4           | 204.1 MB  | ######2    |  63%
# mkl-2019.4           | 204.1 MB  | ######7    |  67%
# mkl-2019.4           | 204.1 MB  | #######1   |  72%
# mkl-2019.4           | 204.1 MB  | #######6   |  76%
# mkl-2019.4           | 204.1 MB  | ########   |  81%
# mkl-2019.4           | 204.1 MB  | ########5  |  85%
# mkl-2019.4           | 204.1 MB  | ########9  |  90%
# mkl-2019.4           | 204.1 MB  | #########4 |  94%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | #########1 |  92%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_011719923a2b78fea7f361db3a50870b/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.gx0qukd6.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults~=1.9.0
#   Downloading azureml_defaults-1.9.0-py3-none-any.whl (3.0 kB)
# Collecting azureml-dataprep[pandas]
#   Downloading azureml_dataprep-2.0.6-py3-none-any.whl (28.2 MB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting werkzeug==0.16.1
#   Downloading Werkzeug-0.16.1-py2.py3-none-any.whl (327 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting azureml-core~=1.9.0
#   Downloading azureml_core-1.9.0-py3-none-any.whl (1.5 MB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.14-py3-none-manylinux1_x86_64.whl (29.3 MB)
# Collecting azureml-dataprep-native<21.0.0,>=20.0.2
#   Downloading azureml_dataprep_native-20.0.2-cp36-cp36m-manylinux1_x86_64.whl (10.7 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.5.0-py3-none-any.whl (22 kB)
# Collecting azure-identity<1.3.0,>=1.2.0
#   Downloading azure_identity-1.2.0-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied, skipping upgrade: numpy<2.0.0,>=1.14.0; extra == "pandas" in /azureml-envs/azureml_011719923a2b78fea7f361db3a50870b/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.gx0qukd6.requirements.txt (line 2)) (1.19.1)
# Requirement already satisfied, skipping upgrade: pandas<2.0.0,>=0.23.4; extra == "pandas" in /azureml-envs/azureml_011719923a2b78fea7f361db3a50870b/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.gx0qukd6.requirements.txt (line 2)) (1.1.0)
# Collecting pyarrow<2.0.0,>=0.17.0; extra == "pandas"
#   Downloading pyarrow-1.0.0-cp36-cp36m-manylinux2014_x86_64.whl (17.2 MB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting azure-mgmt-storage>=1.5.0
#   Downloading azure_mgmt_storage-11.1.0-py2.py3-none-any.whl (547 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.18-py2.py3-none-any.whl (84 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting azure-mgmt-keyvault>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.25-py2.py3-none-any.whl (12 kB)
# Collecting requests>=2.19.1
#   Downloading requests-2.24.0-py2.py3-none-any.whl (61 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.25.10-py2.py3-none-any.whl (127 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.4.1-py2.py3-none-any.whl (36 kB)
# Collecting azure-mgmt-resource>=1.2.1
#   Downloading azure_mgmt_resource-10.2.0-py2.py3-none-any.whl (968 kB)
# Collecting PyJWT
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting azure-mgmt-authorization>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.0-py2.py3-none-any.whl (28 kB)
# Collecting ruamel.yaml>0.16.7
#   Downloading ruamel.yaml-0.16.10-py2.py3-none-any.whl (111 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-3.0-cp35-abi3-manylinux2010_x86_64.whl (2.7 MB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting docker
#   Downloading docker-4.3.0-py2.py3-none-any.whl (145 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.4-py2.py3-none-any.whl (55 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.1.2-py3-none-any.whl (14 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting azure-mgmt-network~=10.0
#   Downloading azure_mgmt_network-10.2.0-py2.py3-none-any.whl (8.6 MB)
# Collecting azure-graphrbac>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting pyopenssl
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Requirement already satisfied, skipping upgrade: pytz in /azureml-envs/azureml_011719923a2b78fea7f361db3a50870b/lib/python3.6/site-packages (from azureml-core~=1.9.0->azureml-defaults~=1.9.0->-r /azureml-environment-setup/condaenv.gx0qukd6.requirements.txt (line 1)) (2020.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /azureml-envs/azureml_011719923a2b78fea7f361db3a50870b/lib/python3.6/site-packages (from azureml-core~=1.9.0->azureml-defaults~=1.9.0->-r /azureml-environment-setup/condaenv.gx0qukd6.requirements.txt (line 1)) (2.8.1)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.4.0.tar.gz (15 kB)
# Requirement already satisfied, skipping upgrade: six>=1.10 in /azureml-envs/azureml_011719923a2b78fea7f361db3a50870b/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.9.0->-r /azureml-environment-setup/condaenv.gx0qukd6.requirements.txt (line 1)) (1.15.0)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.2.zip (177 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting msal-extensions~=0.1.3
#   Downloading msal_extensions-0.1.3-py2.py3-none-any.whl (9.0 kB)
# Collecting msal<2.0.0,>=1.0.0
#   Downloading msal-1.4.3-py2.py3-none-any.whl (49 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.8.0-py2.py3-none-any.whl (121 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (27 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_011719923a2b78fea7f361db3a50870b/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.9.0->azureml-defaults~=1.9.0->-r /azureml-environment-setup/condaenv.gx0qukd6.requirements.txt (line 1)) (2020.6.20)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-1.7.0-py2.py3-none-any.whl (31 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.0-cp36-cp36m-manylinux1_x86_64.whl (548 kB)
# Collecting cffi!=1.11.3,>=1.8
#   Downloading cffi-1.14.1-cp36-cp36m-manylinux1_x86_64.whl (400 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.4.3-py3-none-any.whl (21 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.1.0-py3-none-any.whl (4.9 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Building wheels for collected packages: json-logging-py, liac-arff, dill
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3923 sha256=8310eae6af8e5c94cb1d0033f97a00488800240c37ecc9f23ccfb537e3fcf6d6
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.4.0-py3-none-any.whl size=13333 sha256=86fcf5d3c00ee1dec72d2e4b844567a984fb555987a28d756e513024b813f88b
#   Stored in directory: /root/.cache/pip/wheels/ba/2a/e1/6f7be2e2ea150e2486bff64fd6f0670f4f35f4c8f31c819fb8
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.2-py3-none-any.whl size=78912 sha256=94f1acc9953a833cd0e977f2a4ffb83edfcbd415a5b7c943e26fe4d8e62ef02d
#   Stored in directory: /root/.cache/pip/wheels/02/49/cf/660924cd9bc5fcddc3a0246fe39800c83028d3ccea244de352
# Successfully built json-logging-py liac-arff dill
# Installing collected packages: werkzeug, MarkupSafe, Jinja2, click, itsdangerous, flask, distro, dotnetcore2, azureml-dataprep-native, cloudpickle, portalocker, chardet, urllib3, idna, requests, PyJWT, msal, msal-extensions, pycparser, cffi, cryptography, azure-core, azure-identity, pyarrow, azureml-dataprep, gunicorn, isodate, oauthlib, requests-oauthlib, msrest, azure-common, adal, msrestazure, azure-mgmt-storage, backports.weakref, backports.tempfile, contextlib2, azure-mgmt-keyvault, azure-mgmt-containerregistry, zipp, importlib-metadata, jsonpickle, azure-mgmt-resource, pyopenssl, pyasn1, ndg-httpsclient, azure-mgmt-authorization, pathspec, ruamel.yaml.clib, ruamel.yaml, websocket-client, docker, jeepney, SecretStorage, jmespath, azure-mgmt-network, azure-graphrbac, azureml-core, applicationinsights, liac-arff, dill, azureml-model-management-sdk, json-logging-py, configparser, azureml-defaults
# Successfully installed Jinja2-2.11.2 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.1.2 adal-1.2.4 applicationinsights-0.11.9 azure-common-1.1.25 azure-core-1.8.0 azure-graphrbac-0.61.1 azure-identity-1.2.0 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-network-10.2.0 azure-mgmt-resource-10.2.0 azure-mgmt-storage-11.1.0 azureml-core-1.9.0 azureml-dataprep-2.0.6 azureml-dataprep-native-20.0.2 azureml-defaults-1.9.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.1 chardet-3.0.4 click-7.1.2 cloudpickle-1.5.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.0 dill-0.3.2 distro-1.5.0 docker-4.3.0 dotnetcore2-2.1.14 flask-1.0.3 gunicorn-19.9.0 idna-2.10 importlib-metadata-1.7.0 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.4.3 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-1.4.1 liac-arff-2.4.0 msal-1.4.3 msal-extensions-0.1.3 msrest-0.6.18 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pathspec-0.8.0 portalocker-1.7.1 pyarrow-1.0.0 pyasn1-0.4.8 pycparser-2.20 pyopenssl-19.1.0 requests-2.24.0 requests-oauthlib-1.3.0 ruamel.yaml-0.16.10 ruamel.yaml.clib-0.2.0 urllib3-1.25.10 websocket-client-0.57.0 werkzeug-0.16.1 zipp-3.1.0
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.8.4
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_011719923a2b78fea7f361db3a50870b
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 5c45cdfc941c
#  ---> 5afcd2ebe58b
# Step 9/15 : ENV PATH /azureml-envs/azureml_011719923a2b78fea7f361db3a50870b/bin:$PATH
#  ---> Running in c458a624a130
# Removing intermediate container c458a624a130
#  ---> 1bf51d923723
# Step 10/15 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_011719923a2b78fea7f361db3a50870b
#  ---> Running in 7233d4b9d516
# Removing intermediate container 7233d4b9d516
#  ---> 72c38d8617d1
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_011719923a2b78fea7f361db3a50870b/lib:$LD_LIBRARY_PATH
#  ---> Running in e3cd1fb9267c
# Removing intermediate container e3cd1fb9267c
#  ---> 9467d4575b6c
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> d9c03f417370
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in f31896593034
# Removing intermediate container f31896593034
#  ---> 0da4b28d054a
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in dee91b6500cd
# Removing intermediate container dee91b6500cd
#  ---> ace2491c5ff1
# Step 15/15 : CMD ["bash"]
#  ---> Running in 69057c884011
# Removing intermediate container 69057c884011
#  ---> dcf89f60ce8f
# Successfully built dcf89f60ce8f
# Successfully tagged b1533106f06a49c8a9a7078ce1e0e1a3.azurecr.io/azureml/azureml_7f239797afe41b6f95fac9a660b5e33f:latest
# 2020/08/15 16:11:00 Successfully executed container: acb_step_0
# 2020/08/15 16:11:00 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/08/15 16:11:00 Pushing image: b1533106f06a49c8a9a7078ce1e0e1a3.azurecr.io/azureml/azureml_7f239797afe41b6f95fac9a660b5e33f:latest, attempt 1
# The push refers to repository [b1533106f06a49c8a9a7078ce1e0e1a3.azurecr.io/azureml/azureml_7f239797afe41b6f95fac9a660b5e33f]
# 78af438da53b: Preparing
# 786b8ac2ad68: Preparing
# 3c25f3eba06f: Preparing
# f7cfab2edc70: Preparing
# 8967d97862e7: Preparing
# 5903b8418c1f: Preparing
# f5aa53607bc1: Preparing
# 07eae5ad8c0b: Preparing
# facf43cddd83: Preparing
# 69a9bdc813b0: Preparing
# 7e2b9752143f: Preparing
# 63a67842a4c7: Preparing
# ae3a847dbd6b: Preparing
# 4ae3adcb66cb: Preparing
# aa6685385151: Preparing
# 0040d8f00d7e: Preparing
# 9e6f810a2aab: Preparing
# 5903b8418c1f: Waiting
# f5aa53607bc1: Waiting
# 07eae5ad8c0b: Waiting
# facf43cddd83: Waiting
# 69a9bdc813b0: Waiting
# 7e2b9752143f: Waiting
# 63a67842a4c7: Waiting
# ae3a847dbd6b: Waiting
# 4ae3adcb66cb: Waiting
# aa6685385151: Waiting
# 0040d8f00d7e: Waiting
# 9e6f810a2aab: Waiting
# 8967d97862e7: Pushed
# 3c25f3eba06f: Pushed
# 78af438da53b: Pushed
# f7cfab2edc70: Pushed
# 5903b8418c1f: Pushed
# f5aa53607bc1: Pushed
# 07eae5ad8c0b: Pushed
#
# 63a67842a4c7: Pushed
# facf43cddd83: Pushed
# 4ae3adcb66cb: Pushed
# 7e2b9752143f: Pushed
# aa6685385151: Pushed
# 0040d8f00d7e: Pushed
# 69a9bdc813b0: Pushed
#
# 9e6f810a2aab: Pushed
# ae3a847dbd6b: Pushed
#
# 786b8ac2ad68: Pushed
# latest: digest: sha256:c5c61dad4d1e3c92a4cabbbf52f1fcf98d049ebf8835aab0cf5b5d740599ad73 size: 3883
# 2020/08/15 16:13:14 Successfully pushed image: b1533106f06a49c8a9a7078ce1e0e1a3.azurecr.io/azureml/azureml_7f239797afe41b6f95fac9a660b5e33f:latest
# 2020/08/15 16:13:14 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 216.749259)
# 2020/08/15 16:13:14 Populating digests for step ID: acb_step_0...
# 2020/08/15 16:13:16 Successfully populated digests for step ID: acb_step_0
# 2020/08/15 16:13:16 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 133.966890)
# 2020/08/15 16:13:16 The following dependencies were found:
# 2020/08/15 16:13:16
# - image:
#     registry: b1533106f06a49c8a9a7078ce1e0e1a3.azurecr.io
#     repository: azureml/azureml_7f239797afe41b6f95fac9a660b5e33f
#     tag: latest
#     digest: sha256:c5c61dad4d1e3c92a4cabbbf52f1fcf98d049ebf8835aab0cf5b5d740599ad73
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20200423.v1
#     digest: sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d
#   git: {}
#
# Run ID: ca1 was successful after 5m57s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_17a492bf0f69267b1cfd05356dfa293bfa031dd4735470fa2455544966135af4_d.txt
# ========================================================================================================================
# 2020-08-15T16:18:46Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2020-08-15T16:18:46Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# 2020-08-15T16:18:46Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2020-08-15T16:18:46Z Starting output-watcher...
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_7f239797afe41b6f95fac9a660b5e33f
# fe703b657a32: Pulling fs layer
# f9df1fafd224: Pulling fs layer
# a645a4b887f9: Pulling fs layer
# 57db7fe0b522: Pulling fs layer
# 20b5fabe4f63: Pulling fs layer
# 22898513a7dc: Pulling fs layer
# b77f65fcd9d7: Pulling fs layer
# 132ebd5cd5ca: Pulling fs layer
# 01991399be72: Pulling fs layer
# 60c58ca14ef7: Pulling fs layer
# ca339bb1ce1b: Pulling fs layer
# 4b4c7dcd78ce: Pulling fs layer
# 110d913268af: Pulling fs layer
# ef5bc288d2e9: Pulling fs layer
# 94387fce1ec8: Pulling fs layer
# ae04a23eb84e: Pulling fs layer
# 2ea4109029b7: Pulling fs layer
# 57db7fe0b522: Waiting
# 20b5fabe4f63: Waiting
# 22898513a7dc: Waiting
# b77f65fcd9d7: Waiting
# 132ebd5cd5ca: Waiting
# 01991399be72: Waiting
# 60c58ca14ef7: Waiting
# ca339bb1ce1b: Waiting
# 4b4c7dcd78ce: Waiting
# 110d913268af: Waiting
# ef5bc288d2e9: Waiting
# 94387fce1ec8: Waiting
# ae04a23eb84e: Waiting
# 2ea4109029b7: Waiting
# f9df1fafd224: Verifying Checksum
# f9df1fafd224: Download complete
# 57db7fe0b522: Download complete
# a645a4b887f9: Verifying Checksum
# a645a4b887f9: Download complete
# fe703b657a32: Verifying Checksum
# fe703b657a32: Download complete
# 22898513a7dc: Verifying Checksum
# 22898513a7dc: Download complete
# 20b5fabe4f63: Verifying Checksum
# 20b5fabe4f63: Download complete
# b77f65fcd9d7: Verifying Checksum
# b77f65fcd9d7: Download complete
# 60c58ca14ef7: Verifying Checksum
# 60c58ca14ef7: Download complete
# ca339bb1ce1b: Verifying Checksum
# ca339bb1ce1b: Download complete
# 4b4c7dcd78ce: Verifying Checksum
# 4b4c7dcd78ce: Download complete
# 132ebd5cd5ca: Verifying Checksum
# 132ebd5cd5ca: Download complete
# 110d913268af: Verifying Checksum
# 110d913268af: Download complete
# 94387fce1ec8: Verifying Checksum
# 94387fce1ec8: Download complete
# ef5bc288d2e9: Verifying Checksum
# ef5bc288d2e9: Download complete
# 01991399be72: Verifying Checksum
# 01991399be72: Download complete
# fe703b657a32: Pull complete
# 2ea4109029b7: Verifying Checksum
# 2ea4109029b7: Download complete
# f9df1fafd224: Pull complete
# a645a4b887f9: Pull complete
# 57db7fe0b522: Pull complete
# ae04a23eb84e: Verifying Checksum
# ae04a23eb84e: Download complete
# 20b5fabe4f63: Pull complete
# 22898513a7dc: Pull complete
# b77f65fcd9d7: Pull complete
# 132ebd5cd5ca: Pull complete
# 01991399be72: Pull complete
# 60c58ca14ef7: Pull complete
# ca339bb1ce1b: Pull complete
# 4b4c7dcd78ce: Pull complete
# 110d913268af: Pull complete
# ef5bc288d2e9: Pull complete
# 94387fce1ec8: Pull complete
# ae04a23eb84e: Pull complete
# 2ea4109029b7: Pull complete
# Digest: sha256:c5c61dad4d1e3c92a4cabbbf52f1fcf98d049ebf8835aab0cf5b5d740599ad73
# Status: Downloaded newer image for b1533106f06a49c8a9a7078ce1e0e1a3.azurecr.io/azureml/azureml_7f239797afe41b6f95fac9a660b5e33f:latest
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# [2020-08-15T16:21:40.856447] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['train_diabetes.py', '--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/57b7206e-d68d-451b-8ccb-896341ad878f/mounts/workspaceblobstore/azureml/57b7206e-d68d-451b-8ccb-896341ad878f/model_folder'])
# Starting the daemon thread to refresh tokens in background for process with pid = 109
# Entering Run History Context Manager.
# Current directory:  /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/57b7206e-d68d-451b-8ccb-896341ad878f/mounts/workspaceblobstore/azureml/57b7206e-d68d-451b-8ccb-896341ad878f
# Preparing to call script [ train_diabetes.py ] with arguments: ['--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/57b7206e-d68d-451b-8ccb-896341ad878f/mounts/workspaceblobstore/azureml/57b7206e-d68d-451b-8ccb-896341ad878f/model_folder']
# After variable expansion, calling script [ train_diabetes.py ] with arguments: ['--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/57b7206e-d68d-451b-8ccb-896341ad878f/mounts/workspaceblobstore/azureml/57b7206e-d68d-451b-8ccb-896341ad878f/model_folder']
#
# Script type = None
# Loading Data...
# Training a decision tree model
# Accuracy: 0.8991111111111111
# AUC: 0.884417462026666
# Starting the daemon thread to refresh tokens in background for process with pid = 109
#
#
# The experiment completed successfully. Finalizing run...
# [2020-08-15T16:21:51.819923] TimeoutHandler __init__
# [2020-08-15T16:21:51.820012] TimeoutHandler __enter__
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 2 items cleaning up...
# Cleanup took 1.4980850219726562 seconds
# [2020-08-15T16:21:53.415156] TimeoutHandler __exit__
# 2020/08/15 16:21:57 logger.go:293: Process Exiting with Code:  0
#
# Streaming azureml-logs/75_job_post-tvmps_17a492bf0f69267b1cfd05356dfa293bfa031dd4735470fa2455544966135af4_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-08-15T16:21:58.587050
# Starting job release. Current time:2020-08-15T16:21:59.600981
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 353
# [2020-08-15T16:21:59.615911] Entering context manager injector.
# Job release is complete. Current time:2020-08-15T16:22:02.400422
#
# StepRun(Train Model) Execution Summary
# =======================================
# StepRun( Train Model ) Status: Finished
# {'runId': '57b7206e-d68d-451b-8ccb-896341ad878f', 'target': 'ms-learn-CCryan', 'status': 'Completed', 'startTimeUtc': '2020-08-15T16:18:42.690505Z', 'endTimeUtc': '2020-08-15T16:22:13.922016Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '2c8f348d-25b3-478d-b3ac-16ddad4a7ed6', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '6637b894-0c90-4b60-b102-5c0714ffd674', 'azureml.pipelinerunid': '0ea01d5e-0f18-4409-8fa2-71bd5f36899f', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': 'ff724e6b-83b3-48b7-bd9f-f48d3d6f040c'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_train', 'mechanism': 'Direct'}}], 'runDefinition': {'script': 'train_diabetes.py', 'scriptType': None, 'useAbsolutePath': False, 'arguments': ['--output_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'ms-learn-CCryan', 'dataReferences': {'model_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/57b7206e-d68d-451b-8ccb-896341ad878f/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {'diabetes_train': {'dataLocation': {'dataset': {'id': 'ff724e6b-83b3-48b7-bd9f-f48d3d6f040c', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Direct', 'environmentVariableName': 'diabetes_train', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'diabetes-pipeline-env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.9.0', 'azureml-dataprep[pandas]']}, 'scikit-learn', 'pandas'], 'name': 'azureml_011719923a2b78fea7f361db3a50870b'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200423.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'cmAksCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://mslearnml9203005896.blob.core.windows.net/azureml/ExperimentRun/dcid.57b7206e-d68d-451b-8ccb-896341ad878f/azureml-logs/20_image_build_log.txt?sv=2019-02-02&sr=b&sig=8A%2B8UKFamY8P5KmnGqGjeZ5CxW3TeZpCBZ8N%2FshDWTc%3D&st=2020-08-15T16%3A12%3A05Z&se=2020-08-16T00%3A22%3A05Z&sp=r', 'azureml-logs/55_azureml-execution-tvmps_17a492bf0f69267b1cfd05356dfa293bfa031dd4735470fa2455544966135af4_d.txt': 'https://mslearnml9203005896.blob.core.windows.net/azureml/Ex ...
#
#
#
#
# StepRunId: 91429eeb-5b1d-4bd4-811f-20fc24c9c27c
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/91429eeb-5b1d-4bd4-811f-20fc24c9c27c?wsid=/subscriptions/375be063-544d-4b99-aed9-5a0e16b1f428/resourcegroups/ms-learn-ml/workspaces/ms-learn-ml
# StepRun( Register Model ) Status: NotStarted
# StepRun( Register Model ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_17a492bf0f69267b1cfd05356dfa293bfa031dd4735470fa2455544966135af4_d.txt
# ========================================================================================================================
# 2020-08-15T16:22:50Z Starting output-watcher...
# 2020-08-15T16:22:50Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 1c4608b6763c88c6ea4af5a6342145b8868b50451375d1d8f20ea41b06ea579c
# 2020/08/15 16:22:51 setuptask.go:353: Starting App Insight Logger for task:  containerSetup
# 2020/08/15 16:22:51 logger.go:293: Version: 3.0.01314.0006 Branch: .SourceBranch Commit: 0b1fee2
# 2020/08/15 16:22:51 utils.go:302: /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/08/15 16:22:51 logger.go:293: sshd inside container not required for job, skipping setup.
# 2020/08/15 16:22:52 appinsightlogger.go:40: All App Insights Logs was send successfully
# 2020-08-15T16:22:57Z Job environment preparation succeeded on 10.0.0.5. Output:
# >>>   2020/08/15 16:22:47 setuptask.go:353: Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2020/08/15 16:22:47 logger.go:293: Version: 3.0.01314.0006 Branch: .SourceBranch Commit: 0b1fee2
# >>>   2020/08/15 16:22:47 dynamicconfigs.go:17: Reading dyanamic configs
# >>>   2020/08/15 16:22:47 selfupdate.go:181: Container sas url: https://baiscriptseastusprod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=zEVUlJatOuK%2BQxpWiJMBWPX9cG4lMgbG9SHLlTdHrWo%3D
# >>>   2020/08/15 16:22:47 logger.go:293: [in autoUpgradeFromJobNodeSetup] Is Azsecpack installed false, isEnable false
# >>>   2020/08/15 16:22:47 logger.go:293: azsecpack isEnable:false
# >>>   2020/08/15 16:22:47 logger.go:293: DetonationChamber is not enabled on this subscription: 375be063-544d-4b99-aed9-5a0e16b1f428
# >>>   2020/08/15 16:22:47 logger.go:293: GPU count found: 0
# >>>   2020/08/15 16:22:47 logger.go:293: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/config
# >>>   2020/08/15 16:22:47 logger.go:293: This is not a aml-workstation (compute instance), current offer type: azureml. Starting identity responder as part of prepareJobEnvironment.
# >>>   2020/08/15 16:22:47 logger.go:293: Starting identity responder.
# >>>   2020/08/15 16:22:47 userlogger.go:50: Starting identity responder.
# >>>   2020/08/15 16:22:47 utils.go:314: Failed to open file /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/config/.batchai.IdentityResponder.envlist: open /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/config/.batchai.IdentityResponder.envlist: no such file or directory
# >>>   2020/08/15 16:22:47 logger.go:293: Logfile used for identity responder: /mnt/batch/tasks/workitems/b2e0cd1b-6a47-4dbd-9422-a47f16b4de8a/job-1/91429eeb-5b1d-4bd4-8_27e1cd1f-b8a2-4413-b1bb-8ae357f5c229/IdentityResponderLog-tvmps_17a492bf0f69267b1cfd05356dfa293bfa031dd4735470fa2455544966135af4_d.txt
# >>>   2020/08/15 16:22:47 userlogger.go:50: Logfile used for identity responder: /mnt/batch/tasks/workitems/b2e0cd1b-6a47-4dbd-9422-a47f16b4de8a/job-1/91429eeb-5b1d-4bd4-8_27e1cd1f-b8a2-4413-b1bb-8ae357f5c229/IdentityResponderLog-tvmps_17a492bf0f69267b1cfd05356dfa293bfa031dd4735470fa2455544966135af4_d.txt
# >>>   2020/08/15 16:22:47 logger.go:293: Started Identity Responder for job.
# >>>   2020/08/15 16:22:47 userlogger.go:50: Started Identity Responder for job.
# >>>   2020/08/15 16:22:47 logger.go:293: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/wd
# >>>   2020/08/15 16:22:47 logger.go:293: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/shared
# >>>   2020/08/15 16:22:47 logger.go:293: Mounting job level file systems
# >>>   2020/08/15 16:22:47 logger.go:293: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/mounts
# >>>   2020/08/15 16:22:47 protocol.go:762: Attempting to read datastore credentials file: /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/config/.amlcompute.datastorecredentials
# >>>   2020/08/15 16:22:47 protocol.go:764: Datastore credentials file not found, skipping.
# >>>   2020/08/15 16:22:47 protocol.go:731: Attempting to read runtime sas tokens file: /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/config/.master.runtimesastokens
# >>>   2020/08/15 16:22:47 protocol.go:733: Runtime sas tokens file not found, skipping.
# >>>   2020/08/15 16:22:47 logger.go:293: No NFS configured
# >>>   2020/08/15 16:22:47 logger.go:293: No Azure File Shares configured
# >>>   2020/08/15 16:22:47 logger.go:293: Mounting blob file systems
# >>>   2020/08/15 16:22:47 logger.go:293: Start to pulling docker image: b1533106f06a49c8a9a7078ce1e0e1a3.azurecr.io/azureml/azureml_7f239797afe41b6f95fac9a660b5e33f
# >>>   2020/08/15 16:22:47 logger.go:293: Requesting XDS for registry details.
# >>>   2020/08/15 16:22:47 logger.go:293: Attempt 1 of http call to https://eastus-prodk8ds.batchai.core.windows.net/hosttoolapi/subscriptions/375be063-544d-4b99-aed9-5a0e16b1f428/resourceGroups/ms-learn-ml/workspaces/ms-learn-ml/clusters/ms-learn-ccryan/nodes/tvmps_17a492bf0f69267b1cfd05356dfa293bfa031dd4735470fa2455544966135af4_d?api-version=2018-02-01
# >>>   2020/08/15 16:22:47 logger.go:293: Mounting azureml-blobstore-b1533106-f06a-49c8-a9a7-078ce1e0e1a3 container from mslearnml9203005896 account at /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/mounts/workspaceblobstore
# >>>   2020/08/15 16:22:47 logger.go:293: Using Compute Identity to authenticate Blobfuse: false.
# >>>   2020/08/15 16:22:47 logger.go:293: Using Compute Identity to authenticate Blobfuse: false.
# >>>   2020/08/15 16:22:47 userlogger.go:50: Running following command: &{/bin/bash [bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/configs/workspaceblobstore.cfg --log-level=LOG_WARNING] []  <nil>   [] <nil> <nil> <nil> <nil> <nil> false [] [] [] [] <nil> <nil>}
# >>>   2020/08/15 16:22:47 userlogger.go:50: Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/mounts/workspaceblobstore
# >>>   2020/08/15 16:22:47 logger.go:293: Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/mounts/workspaceblobstore
# >>>   2020/08/15 16:22:47 logger.go:293: Attempt 1. XDS Api returned non-successful ErrorCode: Success
# >>>    ErrorMessage:
# >>>
# >>>   2020/08/15 16:22:47 logger.go:293: Got container registry details from credentials service.
# >>>   2020/08/15 16:22:47 logger.go:293: Writing ACR Details to file...
# >>>   2020/08/15 16:22:47 logger.go:293: Copying ACR Details file to worker nodes...
# >>>   2020/08/15 16:22:47 userlogger.go:50: Executing 'Copy ACR Details file' on 10.0.0.5
# >>>   2020/08/15 16:22:47 userlogger.go:50: Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>   >>>
# >>>   >>>
# >>>   2020/08/15 16:22:47 logger.go:293: Successfully mounted azureml-blobstore-b1533106-f06a-49c8-a9a7-078ce1e0e1a3 container from mslearnml9203005896 account at /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/mounts/workspaceblobstore
# >>>   2020/08/15 16:22:47 logger.go:293: No unmanaged file systems configured
# >>>   2020/08/15 16:22:47 logger.go:293: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/mounts/workspaceblobstore/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/azureml_compute_logs
# >>>   2020/08/15 16:22:47 logger.go:293: Pull docker image time: 609.25769ms
# >>>
# >>>   2020/08/15 16:22:50 logger.go:293: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/mounts/workspaceblobstore/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/logs
# >>>   2020/08/15 16:22:50 logger.go:293: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/mounts/workspaceblobstore/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/outputs
# >>>   2020/08/15 16:22:50 userlogger.go:50: Starting output-watcher...
# >>>   2020/08/15 16:22:50 logger.go:293: Docker Version that this nodes use are: 3.0.1
# >>>
# >>>   2020/08/15 16:22:50 utils.go:302: /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# ...
# >>>   2020/08/15 16:22:52 logger.go:293: runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_011719923a2b78fea7f361db3a50870b/bin/python $AZ_BATCHAI_INPUT_AZUREML/91429eeb-5b1d-4bd4-811f-20fc24c9c27c-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"2c8f348d-25b3-478d-b3ac-16ddad4a7ed6","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/08/15 16:22:52 logger.go:293: runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/mounts/workspaceblobstore/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/azureml_compute_logs/65_job_prep-tvmps_17a492bf0f69267b1cfd05356dfa293bfa031dd4735470fa2455544966135af4_d.txt
# >>>   2020/08/15 16:22:52 logger.go:293: runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/mounts/workspaceblobstore/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/azureml_compute_logs/65_job_prep-tvmps_17a492bf0f69267b1cfd05356dfa293bfa031dd4735470fa2455544966135af4_d.txt
# >>>   2020/08/15 16:22:52 logger.go:293: native cmd: cd /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/mounts/workspaceblobstore/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c;/azureml-envs/azureml_011719923a2b78fea7f361db3a50870b/bin/python /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/mounts/workspaceblobstore/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"2c8f348d-25b3-478d-b3ac-16ddad4a7ed6","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/08/15 16:22:52 logger.go:293: runSpecialJobTask: Running cmd: &{/usr/bin/docker [docker exec -t 91429eeb-5b1d-4bd4-811f-20fc24c9c27c bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;cd /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/mounts/workspaceblobstore/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c;/azureml-envs/azureml_011719923a2b78fea7f361db3a50870b/bin/python /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c/mounts/workspaceblobstore/azureml/91429eeb-5b1d-4bd4-811f-20fc24c9c27c-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"2c8f348d-25b3-478d-b3ac-16ddad4a7ed6","PathStack":["."],"SnapshotEntityId":null}]'] []  <nil> <nil> <nil> [] <nil> <nil> <nil> <nil> <nil> false [] [] [] [] <nil> <nil>}
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:53.023512] Entering job preparation.
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:53.647675] TimeoutHandler __init__
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:53.647742] TimeoutHandler __enter__
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:53.649216] Starting job preparation.
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:53.649264] Extracting the control code.
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:53.682057] fetching and extracting the control code on master node.
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:53.682089] Starting extract_project.
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:53.682174] Starting to extract zip file.
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:54.440016] Finished extracting zip file.
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:54.594180] Using urllib.request Python 3.0 or later
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:54.594255] Start fetching snapshots.
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:54.594296] Start fetching snapshot.
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:54.594313] Retrieving project from snapshot: 2c8f348d-25b3-478d-b3ac-16ddad4a7ed6
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 53
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:54.595497] Start RetrieveProjectSasUrls
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.514500] Finished RetrieveProjectSasUrls
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.514550] TimeoutHandler __init__
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.514568] TimeoutHandler __enter__
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.515804] TimeoutHandler __exit__
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.515856] Starting project file download.
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.515901] Starting _download_tree for file.
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.515997] _download_tree start request for file
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.545233] _download_tree finished request for file
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.545257] _download_tree start writing file
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.545282] TimeoutHandler __init__
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.545289] TimeoutHandler __enter__
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.610805] TimeoutHandler __exit__
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.610839] _download_tree finished writing file
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.610868] Starting _download_tree for file.
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.611329] _download_tree start request for file
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.644259] _download_tree finished request for file
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.644284] _download_tree start writing file
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.644310] TimeoutHandler __init__
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.644319] TimeoutHandler __enter__
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.659926] TimeoutHandler __exit__
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.659958] _download_tree finished writing file
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.659984] Finished project file download.
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.660015] Finished fetching snapshot.
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.660028] Finished fetching snapshots.
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.660037] Finished extract_project.
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.674612] Finished fetching and extracting the control code.
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.677169] downloadDataStore - Download from datastores if requested.
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.678427] Start run_history_prep.
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:55.734947] Entering context manager injector.
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: Acquired lockfile /tmp/91429eeb-5b1d-4bd4-811f-20fc24c9c27c-datastore.lock to downloading input data references
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:56.905047] downloadDataStore completed
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:56.908068] Job preparation is complete.
# >>>   2020/08/15 16:22:56 logger.go:293: runSpecialJobTask: preparation: [2020-08-15T16:22:56.908232] TimeoutHandler __exit__
# >>>   2020/08/15 16:22:57 appinsightlogger.go:40: All App Insights Logs was send successfully
# >>>   2020/08/15 16:22:57 logger.go:293: Process Exiting with Code:  0
# >>>
# 2020-08-15T16:22:58Z 127.0.0.1 slots=2 max-slots=2
# 2020-08-15T16:22:58Z launching Custom job
# 2020-08-15T16:23:04Z job exited with code 0
#
# Streaming azureml-logs/75_job_post-tvmps_17a492bf0f69267b1cfd05356dfa293bfa031dd4735470fa2455544966135af4_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-08-15T16:23:06.189406
# Starting job release. Current time:2020-08-15T16:23:07.210443
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 143
# [2020-08-15T16:23:07.229302] Entering context manager injector.
# Job release is complete. Current time:2020-08-15T16:23:07.739773
#
# StepRun(Register Model) Execution Summary
# ==========================================
# StepRun( Register Model ) Status: Finished
# {'runId': '91429eeb-5b1d-4bd4-811f-20fc24c9c27c', 'target': 'ms-learn-CCryan', 'status': 'Completed', 'startTimeUtc': '2020-08-15T16:22:49.10223Z', 'endTimeUtc': '2020-08-15T16:23:14.284682Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '2c8f348d-25b3-478d-b3ac-16ddad4a7ed6', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '9e6e1e5b-746b-4681-977a-74c448980ea7', 'azureml.pipelinerunid': '0ea01d5e-0f18-4409-8fa2-71bd5f36899f', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'runDefinition': {'script': 'register_diabetes.py', 'scriptType': None, 'useAbsolutePath': False, 'arguments': ['--model_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'ms-learn-CCryan', 'dataReferences': {'model_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/57b7206e-d68d-451b-8ccb-896341ad878f/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'diabetes-pipeline-env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.9.0', 'azureml-dataprep[pandas]']}, 'scikit-learn', 'pandas'], 'name': 'azureml_011719923a2b78fea7f361db3a50870b'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200423.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'cmAksCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_17a492bf0f69267b1cfd05356dfa293bfa031dd4735470fa2455544966135af4_d.txt': 'https://mslearnml9203005896.blob.core.windows.net/azureml/ExperimentRun/dcid.91429eeb-5b1d-4bd4-811f-20fc24c9c27c/azureml-logs/55_azureml-execution-tvmps_17a492bf0f69267b1cfd05356dfa293bfa031dd4735470fa2455544966135af4_d.txt?sv=2019-02-02&sr=b&sig=IFkSm6udkdHEA6Hz%2Ft%2Bt37EOOfHIRUQEXTabIyN2LWY%3D&st=2020-08-15T16%3A13%3A09Z&se=2020-08-16T00%3A23%3A09Z&sp=r', 'azureml-logs/65_job_prep-tvmps_17a492bf0f69267b1cfd05356dfa293bfa031dd4735470fa2455544966135af4_d.txt': 'https://mslearnml9203005896.blob.core.windows.net/azureml/ExperimentRun/dcid.91429eeb-5b1d-4bd4-811f-20fc24c9c27c/azureml-logs/65_job_prep-tvmps_17a492bf0f69267b1cfd05356dfa293bfa031dd4735470fa2455544966135af4_d.txt?sv=2019-02-02&sr=b&sig=Mqbr9sMK8udRLrrJXDAA0aT%2BlOkBY6%2FiIVNBSuGD4zE%3D&st=2020-08-15T16%3A13%3A09Z&se=2020-08- ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '0ea01d5e-0f18-4409-8fa2-71bd5f36899f', 'status': 'Completed', 'startTimeUtc': '2020-08-15T16:06:27.24878Z', 'endTimeUtc': '2020-08-15T16:23:27.13877Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mslearnml9203005896.blob.core.windows.net/azureml/ExperimentRun/dcid.0ea01d5e-0f18-4409-8fa2-71bd5f36899f/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=Js%2BDt06v%2Fqk02CpWQLMMLx9UB5WWT%2BCiVCml2vx9FAk%3D&st=2020-08-15T16%3A01%3A58Z&se=2020-08-16T00%3A11%3A58Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mslearnml9203005896.blob.core.windows.net/azureml/ExperimentRun/dcid.0ea01d5e-0f18-4409-8fa2-71bd5f36899f/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=Dk3fy9I0xTgJ4INh27UhIXwNnkvxptve5laDh5Jv8xc%3D&st=2020-08-15T16%3A01%3A58Z&se=2020-08-16T00%3A11%3A58Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mslearnml9203005896.blob.core.windows.net/azureml/ExperimentRun/dcid.0ea01d5e-0f18-4409-8fa2-71bd5f36899f/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=ZUBYdDzLmOntg2wD5OGreEBMVXun3PubZbG8Np4bcuw%3D&st=2020-08-15T16%3A01%3A59Z&se=2020-08-16T00%3A11%3A59Z&sp=r'}}
# 'Finished'

# %% [markdown]
# The widget above shows details of the pipeline as it runs. You can also monitor pipeline runs in the **Experiments** page in [Azure Machine Learning studio](https://ml.azure.com).
#
# > **Note**: If the widget displays the message `["AttributeError: 'NoneType' object has no attribute 'id'\n"]`, you can safely ignore it!
#
# When the pipeline has finished, a new model should be registered with a *Training context* tag indicating it was trained in a pipeline. Run the following code to verify this.

# %%
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# diabetes_model version: 1
# 	 Training context : Pipeline

# %% [markdown]
# ## Publish the Pipeline
#
# Now that you've created a pipeline and verified it works, you can publish it as a REST service.

# %%
published_pipeline = pipeline.publish(name="Diabetes_Training_Pipeline",
                                      description="Trains diabetes model",
                                      version="1.0")
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://eastus.api.azureml.ms/pipelines/v1.0/subscriptions/375be063-544d-4b99-aed9-5a0e16b1f428/resourceGroups/ms-learn-ml/providers/Microsoft.MachineLearningServices/workspaces/ms-learn-ml/PipelineRuns/PipelineSubmit/4b50d29b-b394-43bf-b246-8182961b2f78

# %% [markdown]
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. A real application would require a service principal with which to be authenticated, but to test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Now you're ready to call the REST interface. The pipeline runs asynchronously, so you'll get an identifier back, which you can use to track the pipeline experiment as it runs:

# %%
import requests
experiment_name = 'Run-diabetes-pipeline'

response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": experiment_name})
run_id = response.json()["Id"]
run_id
# Out:
# '6ef274e9-2237-4868-aa5c-aab566a4ea64'

# %% [markdown]
# Since you have the run ID, you can use the **RunDetails** widget to view the experiment as it runs.
#
# > **Note**: The pipeline should complete quickly, because each step was configured to allow output reuse. This was done primarily for convenience and to save time in this example. In reality, you'd likely want the first step to run every time in case the data has changed, and trigger the subsequent steps only if the output from step one changes.
# >
# > The widget may not refresh quickly enough to indicate that the pipeline run has completed - keep an eye on the kernel indicator at the top right of the page, when it turns from **&#9899;** to **&#9711;**, the code has finished running.

# %%
from azureml.pipeline.core.run import PipelineRun
#from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments[experiment_name], run_id)
#RunDetails(published_pipeline_run).show()
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: 0ea01d5e-0f18-4409-8fa2-71bd5f36899f
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/0ea01d5e-0f18-4409-8fa2-71bd5f36899f?wsid=/subscriptions/375be063-544d-4b99-aed9-5a0e16b1f428/resourcegroups/ms-learn-ml/workspaces/ms-learn-ml
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '0ea01d5e-0f18-4409-8fa2-71bd5f36899f', 'status': 'Completed', 'startTimeUtc': '2020-08-15T16:06:27.24878Z', 'endTimeUtc': '2020-08-15T16:23:27.13877Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mslearnml9203005896.blob.core.windows.net/azureml/ExperimentRun/dcid.0ea01d5e-0f18-4409-8fa2-71bd5f36899f/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=Js%2BDt06v%2Fqk02CpWQLMMLx9UB5WWT%2BCiVCml2vx9FAk%3D&st=2020-08-15T16%3A01%3A58Z&se=2020-08-16T00%3A11%3A58Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mslearnml9203005896.blob.core.windows.net/azureml/ExperimentRun/dcid.0ea01d5e-0f18-4409-8fa2-71bd5f36899f/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=Dk3fy9I0xTgJ4INh27UhIXwNnkvxptve5laDh5Jv8xc%3D&st=2020-08-15T16%3A01%3A58Z&se=2020-08-16T00%3A11%3A58Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mslearnml9203005896.blob.core.windows.net/azureml/ExperimentRun/dcid.0ea01d5e-0f18-4409-8fa2-71bd5f36899f/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=ZUBYdDzLmOntg2wD5OGreEBMVXun3PubZbG8Np4bcuw%3D&st=2020-08-15T16%3A01%3A59Z&se=2020-08-16T00%3A11%3A59Z&sp=r'}}
# 'Finished'

# %% [markdown]
# This is a simple example, designed to demonstrate the principle. In reality, you could build more sophisticated logic into the pipeline steps - for example, evaluating the model against some test data to calculate a performance metric like AUC or accuracy, comparing the metric to that of any previously registered versions of the model, and only registering the new model if it performs better.
#
# You can use the [Azure Machine Learning extension for Azure DevOps](https://marketplace.visualstudio.com/items?itemName=ms-air-aiagility.vss-services-azureml) to combine Azure ML pipelines with Azure DevOps pipelines (yes, it *is* confusing that they have the same name!) and integrate model retraining into a *continuous integration/continuous deployment (CI/CD)* process. For example you could use an Azure DevOps *build* pipeline to trigger an Azure ML pipeline that trains and registers a model, and when the model is registered it could trigger an Azure Devops *release* pipeline that deploys the model as a web service, along with the application or service that consumes the model.
