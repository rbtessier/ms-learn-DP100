# %% [markdown]
# # Interpreting Models
#
# You can use Azure Machine Learning to interpret a model by using an *explainer* that quantifies the amount of influence each feature contribues to the predicted label. There are many common explainers, each suitable for different kinds of modeling algorithm; but the basic approach to using them is the same.
#
# ## Before You Start
#
# Before you start this lab, ensure that you have completed the *Create an Azure Machine Learning Workspace* and *Create a Compute Instance* tasks in [Lab 1: Getting Started with Azure Machine Learning](./labdocs/Lab01.md). Then open this notebook in Jupyter on your Compute Instance.
#
# Then run the following cell to ensure that you have the latest version of the Azure ML SDK installed, and in addition install the Azure ML Interpretability library. You can use this to interpret many typical kinds of model, even if they haven't been trained in an Azure ML experiment or registered in an Azure ML workspace.

# %%
# !pip install --upgrade azureml-sdk[notebooks,automl,explain]
# !pip install --upgrade azureml-interpret
# Out:
# Collecting azureml-sdk[automl,explain,notebooks]
#   Using cached azureml_sdk-1.12.0-py3-none-any.whl (4.4 kB)
# Collecting azureml-pipeline~=1.12.0
#   Using cached azureml_pipeline-1.12.0-py3-none-any.whl (3.7 kB)
# Collecting azureml-train-automl-client~=1.12.0
#   Using cached azureml_train_automl_client-1.12.0-py3-none-any.whl (98 kB)
# Collecting azureml-train~=1.12.0
#   Using cached azureml_train-1.12.0-py3-none-any.whl (3.2 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.12.0
#   Using cached azureml_dataset_runtime-1.12.0-py3-none-any.whl (3.2 kB)
# Collecting azureml-core~=1.12.0
#   Using cached azureml_core-1.12.0.post1-py3-none-any.whl (2.0 MB)
# Collecting azureml-train-automl~=1.12.0; extra == "automl"
#   Using cached azureml_train_automl-1.12.0-py3-none-any.whl (3.4 kB)
# Collecting azureml-explain-model~=1.12.0; extra == "explain"
#   Using cached azureml_explain_model-1.12.0-py3-none-any.whl (22 kB)
# Collecting azureml-widgets~=1.12.0; extra == "notebooks"
#   Using cached azureml_widgets-1.12.0-py3-none-any.whl (14.1 MB)
# Collecting azureml-contrib-notebook~=1.12.0; extra == "notebooks"
#   Using cached azureml_contrib_notebook-1.12.0-py3-none-any.whl (29 kB)
# Collecting azureml-pipeline-core~=1.12.0
#   Using cached azureml_pipeline_core-1.12.0-py3-none-any.whl (300 kB)
# Collecting azureml-pipeline-steps~=1.12.0
#   Using cached azureml_pipeline_steps-1.12.0-py3-none-any.whl (59 kB)
# Collecting azureml-automl-core~=1.12.0
#   Using cached azureml_automl_core-1.12.0-py3-none-any.whl (158 kB)
# Collecting azureml-telemetry~=1.12.0
#   Using cached azureml_telemetry-1.12.0-py3-none-any.whl (29 kB)
# Collecting azureml-train-core~=1.12.0
#   Using cached azureml_train_core-1.12.0-py3-none-any.whl (8.6 MB)
# Collecting azureml-dataprep<2.1.0a,>=2.0.1a
#   Using cached azureml_dataprep-2.0.7-py3-none-any.whl (28.2 MB)
# Collecting pyarrow<2.0.0,>=0.17.0
#   Using cached pyarrow-1.0.0-cp38-cp38-win_amd64.whl (10.5 MB)
# Requirement already satisfied, skipping upgrade: fusepy<4.0.0,>=3.0.1; extra == "fuse" in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-dataset-runtime[fuse]~=1.12.0->azureml-sdk[automl,explain,notebooks]) (3.0.1)
# Requirement already satisfied, skipping upgrade: azure-mgmt-keyvault>=0.40.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (2.2.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (2.8.1)
# Requirement already satisfied, skipping upgrade: azure-mgmt-containerregistry>=2.0.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (2.8.0)
# Requirement already satisfied, skipping upgrade: ndg-httpsclient in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (0.5.1)
# Requirement already satisfied, skipping upgrade: urllib3>=1.23 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (1.25.9)
# Requirement already satisfied, skipping upgrade: pyopenssl in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (19.1.0)
# Requirement already satisfied, skipping upgrade: azure-graphrbac>=0.40.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (0.61.1)
# Requirement already satisfied, skipping upgrade: msrest>=0.5.1 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (0.6.17)
# Requirement already satisfied, skipping upgrade: azure-mgmt-storage>=1.5.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (11.1.0)
# Requirement already satisfied, skipping upgrade: contextlib2 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (0.6.0.post1)
# Requirement already satisfied, skipping upgrade: SecretStorage in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (3.1.2)
# Requirement already satisfied, skipping upgrade: PyJWT in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (1.7.1)
# Requirement already satisfied, skipping upgrade: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.* in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (2.9.2)
# Requirement already satisfied, skipping upgrade: jmespath in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (0.10.0)
# Collecting backports.tempfile
#   Using cached backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied, skipping upgrade: azure-common>=1.1.12 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (1.1.25)
# Requirement already satisfied, skipping upgrade: requests>=2.19.1 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (2.24.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-authorization>=0.40.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (0.60.0)
# Requirement already satisfied, skipping upgrade: jsonpickle in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (1.4.1)
# Requirement already satisfied, skipping upgrade: adal>=1.2.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (1.2.4)
# Requirement already satisfied, skipping upgrade: pathspec in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (0.8.0)
# Requirement already satisfied, skipping upgrade: docker in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (4.2.2)
# Requirement already satisfied, skipping upgrade: pytz in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (2020.1)
# Requirement already satisfied, skipping upgrade: msrestazure>=0.4.33 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (0.6.4)
# Collecting ruamel.yaml>=0.15.35
#   Using cached ruamel.yaml-0.16.10-py2.py3-none-any.whl (111 kB)
# Requirement already satisfied, skipping upgrade: azure-mgmt-resource>=1.2.1 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (10.1.0)
# Collecting azureml-automl-runtime~=1.12.0
#   Using cached azureml_automl_runtime-1.12.0-py3-none-any.whl (1.9 MB)
# Collecting azureml-train-automl-runtime~=1.12.0
#   Using cached azureml_train_automl_runtime-1.12.0-py3-none-any.whl (101 kB)
# Collecting azureml-interpret~=1.12.0
#   Using cached azureml_interpret-1.12.0-py3-none-any.whl (47 kB)
# Requirement already satisfied, skipping upgrade: ipywidgets>=7.0.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-widgets~=1.12.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (7.5.1)
# Requirement already satisfied, skipping upgrade: ipython in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-contrib-notebook~=1.12.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (7.16.1)
# Requirement already satisfied, skipping upgrade: ipykernel in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-contrib-notebook~=1.12.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (5.3.2)
# Requirement already satisfied, skipping upgrade: papermill<2 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-contrib-notebook~=1.12.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (1.2.1)
# Requirement already satisfied, skipping upgrade: applicationinsights in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-telemetry~=1.12.0->azureml-train-automl-client~=1.12.0->azureml-sdk[automl,explain,notebooks]) (0.11.9)
# Collecting azureml-train-restclients-hyperdrive~=1.12.0
#   Using cached azureml_train_restclients_hyperdrive-1.12.0-py3-none-any.whl (18 kB)
# Collecting azureml-dataprep-native<21.0.0,>=20.0.2
#   Using cached azureml_dataprep_native-20.0.2-cp38-cp38-win_amd64.whl (7.8 MB)
# Requirement already satisfied, skipping upgrade: azure-identity<1.3.0,>=1.2.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-dataprep<2.1.0a,>=2.0.1a->azureml-dataset-runtime[fuse]~=1.12.0->azureml-sdk[automl,explain,notebooks]) (1.2.0)
# Requirement already satisfied, skipping upgrade: cloudpickle<2.0.0,>=1.1.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-dataprep<2.1.0a,>=2.0.1a->azureml-dataset-runtime[fuse]~=1.12.0->azureml-sdk[automl,explain,notebooks]) (1.5.0)
# Requirement already satisfied, skipping upgrade: dotnetcore2<3.0.0,>=2.1.14 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-dataprep<2.1.0a,>=2.0.1a->azureml-dataset-runtime[fuse]~=1.12.0->azureml-sdk[automl,explain,notebooks]) (2.1.14)
# Requirement already satisfied, skipping upgrade: numpy>=1.14 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from pyarrow<2.0.0,>=0.17.0->azureml-dataset-runtime[fuse]~=1.12.0->azureml-sdk[automl,explain,notebooks]) (1.19.0)
# Requirement already satisfied, skipping upgrade: six>=1.5 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil>=2.7.3->azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (1.15.0)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.1 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from ndg-httpsclient->azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (0.4.8)
# Requirement already satisfied, skipping upgrade: isodate>=0.6.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from msrest>=0.5.1->azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (0.6.0)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from msrest>=0.5.1->azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (2020.6.20)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.5.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from msrest>=0.5.1->azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (1.3.0)
# Requirement already satisfied, skipping upgrade: jeepney>=0.4.2 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from SecretStorage->azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (0.4.3)
# Requirement already satisfied, skipping upgrade: cffi!=1.11.3,>=1.8 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (1.14.0)
# Collecting backports.weakref
#   Using cached backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.19.1->azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.19.1->azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (3.0.4)
# Requirement already satisfied, skipping upgrade: importlib-metadata in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from jsonpickle->azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (1.7.0)
# Requirement already satisfied, skipping upgrade: pypiwin32==223; sys_platform == "win32" and python_version >= "3.6" in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from docker->azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (223)
# Requirement already satisfied, skipping upgrade: websocket-client>=0.32.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from docker->azureml-core~=1.12.0->azureml-sdk[automl,explain,notebooks]) (0.57.0)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Using cached ruamel.yaml.clib-0.2.0.tar.gz (178 kB)
# Collecting psutil<6.0.0,>=5.2.2
#   Downloading psutil-5.7.2-cp38-cp38-win_amd64.whl (243 kB)
# Collecting scikit-learn<=0.20.3,>=0.19.0
#   Using cached scikit-learn-0.20.3.tar.gz (11.8 MB)
# Collecting onnx<=1.6.0,>=1.5.0
#   Using cached onnx-1.6.0.tar.gz (3.1 MB)
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\users\ryan\appdata\local\programs\python\python38\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Ryan\\AppData\\Local\\Temp\\pip-install-lf8eg332\\onnx\\setup.py'"'"'; __file__='"'"'C:\\Users\\Ryan\\AppData\\Local\\Temp\\pip-install-lf8eg332\\onnx\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Ryan\AppData\Local\Temp\pip-pip-egg-info-n3amb5bx'
#          cwd: C:\Users\Ryan\AppData\Local\Temp\pip-install-lf8eg332\onnx\
#     Complete output (5 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Ryan\AppData\Local\Temp\pip-install-lf8eg332\onnx\setup.py", line 72, in <module>
#         assert CMAKE, 'Could not find "cmake" executable!'
#     AssertionError: Could not find "cmake" executable!
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# WARNING: You are using pip version 20.2; however, version 20.2.2 is available.
# You should consider upgrading via the 'c:\users\ryan\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.
# Collecting azureml-interpret
#   Using cached azureml_interpret-1.12.0-py3-none-any.whl (47 kB)
# Collecting interpret-community==0.14.*
#   Using cached interpret_community-0.14.3-py3-none-any.whl (5.9 MB)
# Collecting shap<=0.34.0,>=0.20.0
#   Downloading shap-0.34.0.tar.gz (264 kB)
# Requirement already satisfied, skipping upgrade: pandas in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from interpret-community==0.14.*->azureml-interpret) (1.0.5)
# Collecting interpret-core[required]<=0.2.1,>=0.1.20
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\users\ryan\appdata\local\programs\python\python38\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Ryan\\AppData\\Local\\Temp\\pip-install-1y16brna\\shap\\setup.py'"'"'; __file__='"'"'C:\\Users\\Ryan\\AppData\\Local\\Temp\\pip-install-1y16brna\\shap\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Ryan\AppData\Local\Temp\pip-record-1lgzxtla\install-record.txt' --single-version-externally-managed --compile --install-headers 'c:\users\ryan\appdata\local\programs\python\python38\Include\shap'
#          cwd: C:\Users\Ryan\AppData\Local\Temp\pip-install-1y16brna\shap\
#     Complete output (64 lines):
#     running install
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.8
#     creating build\lib.win-amd64-3.8\shap
#     copying shap\common.py -> build\lib.win-amd64-3.8\shap
#     copying shap\datasets.py -> build\lib.win-amd64-3.8\shap
#     copying shap\__init__.py -> build\lib.win-amd64-3.8\shap
#     creating build\lib.win-amd64-3.8\shap\explainers
#     copying shap\explainers\bruteforce.py -> build\lib.win-amd64-3.8\shap\explainers
#     copying shap\explainers\explainer.py -> build\lib.win-amd64-3.8\shap\explainers
#     copying shap\explainers\gradient.py -> build\lib.win-amd64-3.8\shap\explainers
#     copying shap\explainers\kernel.py -> build\lib.win-amd64-3.8\shap\explainers
#     copying shap\explainers\linear.py -> build\lib.win-amd64-3.8\shap\explainers
#     copying shap\explainers\mimic.py -> build\lib.win-amd64-3.8\shap\explainers
#     copying shap\explainers\partition.py -> build\lib.win-amd64-3.8\shap\explainers
#     copying shap\explainers\permutation.py -> build\lib.win-amd64-3.8\shap\explainers
#     copying shap\explainers\pytree.py -> build\lib.win-amd64-3.8\shap\explainers
#     copying shap\explainers\sampling.py -> build\lib.win-amd64-3.8\shap\explainers
#   Using cached interpret_core-0.2.1-py3-none-any.whl (5.0 MB)
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from interpret-community==0.14.*->azureml-interpret) (0.23.1)
# Requirement already satisfied, skipping upgrade: numpy in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from interpret-community==0.14.*->azureml-interpret) (1.19.0)
# Requirement already satisfied, skipping upgrade: packaging in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from interpret-community==0.14.*->azureml-interpret) (20.4)
# Requirement already satisfied, skipping upgrade: scipy in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from interpret-community==0.14.*->azureml-interpret) (1.5.2)
# Requirement already satisfied, skipping upgrade: tqdm>4.25.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from shap<=0.34.0,>=0.20.0->interpret-community==0.14.*->azureml-interpret) (4.48.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from pandas->interpret-community==0.14.*->azureml-interpret) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from pandas->interpret-community==0.14.*->azureml-interpret) (2020.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11; extra == "required" in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from interpret-core[required]<=0.2.1,>=0.1.20->interpret-community==0.14.*->azureml-interpret) (0.16.0)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn->interpret-community==0.14.*->azureml-interpret) (2.1.0)
# Requirement already satisfied, skipping upgrade: six in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from packaging->interpret-community==0.14.*->azureml-interpret) (1.15.0)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from packaging->interpret-community==0.14.*->azureml-interpret) (2.4.7)
# Using legacy 'setup.py install' for shap, since package 'wheel' is not installed.
# Installing collected packages: shap, interpret-core, interpret-community, azureml-interpret
#     Running setup.py install for shap: started
#     Running setup.py install for shap: finished with status 'error'
#     copying shap\explainers\tree.py -> build\lib.win-amd64-3.8\shap\explainers
#     copying shap\explainers\__init__.py -> build\lib.win-amd64-3.8\shap\explainers
#     creating build\lib.win-amd64-3.8\shap\explainers\other
#     copying shap\explainers\other\coefficent.py -> build\lib.win-amd64-3.8\shap\explainers\other
#     copying shap\explainers\other\lime.py -> build\lib.win-amd64-3.8\shap\explainers\other
#     copying shap\explainers\other\maple.py -> build\lib.win-amd64-3.8\shap\explainers\other
#     copying shap\explainers\other\random.py -> build\lib.win-amd64-3.8\shap\explainers\other
#     copying shap\explainers\other\treegain.py -> build\lib.win-amd64-3.8\shap\explainers\other
#     copying shap\explainers\other\__init__.py -> build\lib.win-amd64-3.8\shap\explainers\other
#     creating build\lib.win-amd64-3.8\shap\explainers\deep
#     copying shap\explainers\deep\deep_pytorch.py -> build\lib.win-amd64-3.8\shap\explainers\deep
#     copying shap\explainers\deep\deep_tf.py -> build\lib.win-amd64-3.8\shap\explainers\deep
#     copying shap\explainers\deep\__init__.py -> build\lib.win-amd64-3.8\shap\explainers\deep
#     creating build\lib.win-amd64-3.8\shap\plots
#     copying shap\plots\bar.py -> build\lib.win-amd64-3.8\shap\plots
#     copying shap\plots\colorconv.py -> build\lib.win-amd64-3.8\shap\plots
#     copying shap\plots\colors.py -> build\lib.win-amd64-3.8\shap\plots
#     copying shap\plots\decision.py -> build\lib.win-amd64-3.8\shap\plots
#     copying shap\plots\dependence.py -> build\lib.win-amd64-3.8\shap\plots
#     copying shap\plots\embedding.py -> build\lib.win-amd64-3.8\shap\plots
#     copying shap\plots\force.py -> build\lib.win-amd64-3.8\shap\plots
#     copying shap\plots\force_matplotlib.py -> build\lib.win-amd64-3.8\shap\plots
#     copying shap\plots\image.py -> build\lib.win-amd64-3.8\shap\plots
#     copying shap\plots\monitoring.py -> build\lib.win-amd64-3.8\shap\plots
#     copying shap\plots\partial_dependence.py -> build\lib.win-amd64-3.8\shap\plots
#     copying shap\plots\summary.py -> build\lib.win-amd64-3.8\shap\plots
#     copying shap\plots\waterfall.py -> build\lib.win-amd64-3.8\shap\plots
#     copying shap\plots\__init__.py -> build\lib.win-amd64-3.8\shap\plots
#     creating build\lib.win-amd64-3.8\shap\benchmark
#     copying shap\benchmark\experiments.py -> build\lib.win-amd64-3.8\shap\benchmark
#     copying shap\benchmark\measures.py -> build\lib.win-amd64-3.8\shap\benchmark
#     copying shap\benchmark\methods.py -> build\lib.win-amd64-3.8\shap\benchmark
#     copying shap\benchmark\metrics.py -> build\lib.win-amd64-3.8\shap\benchmark
#     copying shap\benchmark\models.py -> build\lib.win-amd64-3.8\shap\benchmark
#     copying shap\benchmark\plots.py -> build\lib.win-amd64-3.8\shap\benchmark
#     copying shap\benchmark\__init__.py -> build\lib.win-amd64-3.8\shap\benchmark
#     creating build\lib.win-amd64-3.8\shap\plots\resources
#     copying shap\plots\resources\bundle.js -> build\lib.win-amd64-3.8\shap\plots\resources
#     copying shap\plots\resources\logoSmallGray.png -> build\lib.win-amd64-3.8\shap\plots\resources
#     copying shap\tree_shap.h -> build\lib.win-amd64-3.8\shap
#     running build_ext
#     numpy.get_include() c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages\numpy\core\include
#     building 'shap._cext' extension
#     error: Microsoft Visual C++ 14.0 is required. Get it with "Build Tools for Visual Studio": https://visualstudio.microsoft.com/downloads/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'c:\users\ryan\appdata\local\programs\python\python38\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Ryan\\AppData\\Local\\Temp\\pip-install-1y16brna\\shap\\setup.py'"'"'; __file__='"'"'C:\\Users\\Ryan\\AppData\\Local\\Temp\\pip-install-1y16brna\\shap\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Ryan\AppData\Local\Temp\pip-record-1lgzxtla\install-record.txt' --single-version-externally-managed --compile --install-headers 'c:\users\ryan\appdata\local\programs\python\python38\Include\shap' Check the logs for full command output.
# WARNING: You are using pip version 20.2; however, version 20.2.2 is available.
# You should consider upgrading via the 'c:\users\ryan\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ## Explain a Model
#
# Let's start with a model that is trained outside of Azure Machine Learning - Run the cell below to train a decision tree classification model.

# %%
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# load the diabetes dataset
print("Loading Data...")
data = pd.read_csv('data/diabetes.csv')

# Separate features and labels
features = ['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']
labels = ['not-diabetic', 'diabetic']
X, y = data[features].values, data['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train a decision tree model
print('Training a decision tree model')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))

print('Model trained.')

# %% [markdown]
# The training process generated some model evaluation metrics based on a hold-back validation dataset, so you have an idea of how accurately it predicts; but how do the features in the data influence the prediction?

# %% [markdown]
# ### Get an Explainer for our Model
#
# Let's get a suitable explainer for the model from the Azure ML interpretability library you installed earlier. There are many kinds of explainer. In this example you'll use a *Tabular Explainer*, which is a "black box" explainer that can be used to explain many kinds of model by invoking an appropriate [SHAP](https://github.com/slundberg/shap) model explainer.

# %%
from interpret.ext.blackbox import TabularExplainer

# "features" and "classes" fields are optional
tab_explainer = TabularExplainer(model, 
                             X_train, 
                             features=features, 
                             classes=labels)
print(tab_explainer, "ready!")

# %% [markdown]
# ### Get Global Feature Importance
#
# The first thing to do is try to explain the model by evaluating the overall *feature importance* - in other words, quantifying the extent to which each feature influences the prediction based on the whole training dataset.

# %%
# you can use the training data or the test data here
global_tab_explanation = tab_explainer.explain_global(X_train)

# Get the top features by importance
global_tab_feature_importance = global_tab_explanation.get_feature_importance_dict()
for feature, importance in global_tab_feature_importance.items():
    print(feature,":", importance)

# %% [markdown]
# The feature importance is ranked, with the most important feature listed first.
#
# ### Get Local Feature Importance
#
# So you have an overall view, but what about explaining individual observations? Let's generate *local* explanations for individual predictions, quantifying the extent to which each feature influenced the decision to predict each of the possible label values. In this case, it's a binary model, so there are two possible labels (non-diabetic and diabetic); and you can quantify the influence of each feature for each of these label values for individual observations in a dataset. You'll just evaluate the first two cases in the test dataset.

# %%
# Get the observations we want to explain (the first two)
X_explain = X_test[0:2]

# Get predictions
predictions = model.predict(X_explain)

# Get local explanations
local_tab_explanation = tab_explainer.explain_local(X_explain)

# Get feature names and importance for each possible label
local_tab_features = local_tab_explanation.get_ranked_local_names()
local_tab_importance = local_tab_explanation.get_ranked_local_values()

for l in range(len(local_tab_features)):
    print('Support for', labels[l])
    label = local_tab_features[l]
    for o in range(len(label)):
        print("\tObservation", o + 1)
        feature_list = label[o]
        total_support = 0
        for f in range(len(feature_list)):
            print("\t\t", feature_list[f], ':', local_tab_importance[l][o][f])
            total_support += local_tab_importance[l][o][f]
        print("\t\t ----------\n\t\t Total:", total_support, "Prediction:", labels[predictions[o]])

# %% [markdown]
# ## Adding Explainability to Azure ML Models Training Experiments
#
# As you've seen, you can generate explanations for models trained outside of Azure ML; but when you use experiments to train models in your Azure ML workspace, you can generate model explanations and log them.
#
# ### Connect to Your Workspace
#
# To run an experiment, you need to connect to your workspace using the Azure ML SDK.
#
# > **Note**: You may be prompted to authenticate. Just copy the code and click the link provided to sign into your Azure subscription, and then return to this notebook.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))

# %% [markdown]
# ### Train and Explain a Model using an Experiment
#
# OK, let's create an experiment and put the files it needs in a local folder - in this case we'll just use the same CSV file of diabetes data to train the model.

# %%
import os, shutil
from azureml.core import Experiment

# Create a folder for the experiment files
experiment_folder = 'diabetes_train_and_explain'
os.makedirs(experiment_folder, exist_ok=True)

# Copy the data file into the experiment folder
shutil.copy('data/diabetes.csv', os.path.join(experiment_folder, "diabetes.csv"))

# %% [markdown]
# Now we'll create a training script that looks similar to any other Azure ML training script except that is includes the following features:
#
# - The same libraries to generate model explanations we used before are imported and used to generate a global explanation
# - The **ExplanationClient** library is used to upload the explanation to the experiment output

# %%
# %%writefile $experiment_folder/diabetes_training.py
# Import libraries
import os
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# Import Azure ML run library
from azureml.core.run import Run

# Import libraries for model explanation
from azureml.contrib.interpret.explanation.explanation_client import ExplanationClient
from interpret.ext.blackbox import TabularExplainer

# Get the experiment run context
run = Run.get_context()

# load the diabetes dataset
print("Loading Data...")
data = pd.read_csv('diabetes.csv')

features = ['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']
labels = ['not-diabetic', 'diabetic']

# Separate features and labels
X, y = data[features].values, data['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train a decision tree model
print('Training a decision tree model')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
run.log('AUC', np.float(auc))

os.makedirs('outputs', exist_ok=True)
# note file saved in the outputs folder is automatically uploaded into experiment record
joblib.dump(value=model, filename='outputs/diabetes.pkl')

# Get explanation
explainer = TabularExplainer(model, X_train, features=features, classes=labels)
explanation = explainer.explain_global(X_test)

# Get an Explanation Client and upload the explanation
explain_client = ExplanationClient.from_run(run)
explain_client.upload_model_explanation(explanation, comment='Tabular Explanation')

# Complete the run
run.complete()

# %% [markdown]
# Now you can run the experiment, using an estimator to run the training script. Note that the **azureml-interpret** library is included in the training environment so the script can create a **TabularExplainer**, and the **azureml-contrib-interpret** package is included so the script can use the **ExplainerClient** class.

# %%
from azureml.train.estimator import Estimator
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.widgets import RunDetails

# Create a Python environment for the experiment
env = Environment('diabetes-interpret-env')
env.python.user_managed_dependencies = False # Let Azure ML manage dependencies
env.docker.enabled = True # Use a docker container

# Create a set of package dependencies (including the azureml-contrib-interpret package)
packages = CondaDependencies.create(conda_packages=['scikit-learn','pandas'],
                                    pip_packages=['azureml-defaults','azureml-interpret','azureml-contrib-interpret'])

# Add the dependencies to the environment
env.python.conda_dependencies = packages

# Create an estimator
estimator = Estimator(source_directory=experiment_folder,
              compute_target = 'local', # Use local compute
              environment_definition = env,
              entry_script='diabetes_training.py')

# Run the experiment
experiment = Experiment(workspace = ws, name = 'diabetes_train_and_explain')
run = experiment.submit(config=estimator)
RunDetails(run).show()
run.wait_for_completion()

# %% [markdown]
# ## Retrieve the Feature Importance Values
#
# With the experiment run completed, you can use the **ExplanationClient** class to retrieve the feature importance from the explanation registered for the run.

# %%
from azureml.contrib.interpret.explanation.explanation_client import ExplanationClient

# Get the feature explanations
client = ExplanationClient.from_run(run)
engineered_explanations = client.download_model_explanation()
feature_importances = engineered_explanations.get_feature_importance_dict()

# Overall feature importance
print('Feature\tImportance')
for key, value in feature_importances.items():
    print(key, '\t', value)

# %% [markdown]
# ## View the Model Explanation in Azure Machine Learning studio
#
# You can also click the link in the Run Details widget to see the run in Azure Machine Learning studio, and view the **Explanations** tab. Then:
#
# 1. Select the **Tabular Explanation** explainer.
# 2. View the **Global Importance** chart, which shows the overall global feature importance.
# 3. View the **Summary Importance** chart, which shows each data point from the test data in a *swarm*, *violin*, or *box* plot.
# 4. Select an individual point to see the **Local Feature Importance** for the individual prediction for the selected data point.

# %% [markdown]
# **More Information**: For more information about using explainers in Azure ML, see [the documentation](https://docs.microsoft.com/azure/machine-learning/how-to-machine-learning-interpretability).
