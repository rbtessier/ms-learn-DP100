# %% [markdown]
# # Creating a Batch Inferencing Service
#
# In previous labs, you used an Azure ML *pipeline* to automate the training and registration of a model, and you published a model as a web service for real-time *inferencing* (getting predictions from a model). Now you'll combine these two concepts to create a pipeline for *batch inferencing*. What does that mean? Well, imagine a health clinic takes patient measurements all day, saving the details for each patient in a separate file. Then overnight, the diabetes prediction model can be used to process all of the day's patient data as a batch, generating predictions that will be waiting the following morning so that the clinic can follow up with patients who are predicted to be at risk of diabetes. That's what you'll implement in this exercise.
#
# ## Before You Start
#
# Before you start this lab, ensure that you have completed the *Create an Azure Machine Learning Workspace* and *Create a Compute Instance* tasks in [Lab 1: Getting Started with Azure Machine Learning](./labdocs/Lab01.md). Then open this notebook in Jupyter on your Compute Instance.
#
# Let's start by ensuring that you have the latest version of the Azure ML SDK installed.

# %%
# !pip install --upgrade azureml-sdk[notebooks,automl,explain]
# Out:
# Collecting azureml-sdk[automl,explain,notebooks]
#   Downloading azureml_sdk-1.11.0-py3-none-any.whl (4.4 kB)
# Collecting azureml-pipeline~=1.11.0
#   Downloading azureml_pipeline-1.11.0-py3-none-any.whl (3.7 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.11.0
#   Downloading azureml_dataset_runtime-1.11.0.post1-py3-none-any.whl (3.3 kB)
# Collecting azureml-train-automl-client~=1.11.0
#   Downloading azureml_train_automl_client-1.11.0.post1-py3-none-any.whl (97 kB)
# Collecting azureml-train~=1.11.0
#   Downloading azureml_train-1.11.0-py3-none-any.whl (3.2 kB)
# Collecting azureml-core~=1.11.0
#   Downloading azureml_core-1.11.0.post1-py3-none-any.whl (2.0 MB)
# Collecting azureml-train-automl~=1.11.0; extra == "automl"
#   Downloading azureml_train_automl-1.11.0-py3-none-any.whl (3.4 kB)
# Collecting azureml-explain-model~=1.11.0; extra == "explain"
#   Downloading azureml_explain_model-1.11.0-py3-none-any.whl (22 kB)
# Collecting azureml-contrib-notebook~=1.11.0; extra == "notebooks"
#   Downloading azureml_contrib_notebook-1.11.0-py3-none-any.whl (29 kB)
# Collecting azureml-widgets~=1.11.0; extra == "notebooks"
#   Downloading azureml_widgets-1.11.0-py3-none-any.whl (14.1 MB)
# Collecting azureml-pipeline-core~=1.11.0
#   Downloading azureml_pipeline_core-1.11.0-py3-none-any.whl (295 kB)
# Collecting azureml-pipeline-steps~=1.11.0
#   Downloading azureml_pipeline_steps-1.11.0-py3-none-any.whl (58 kB)
# Collecting pyarrow<1.0.0,>=0.17.0
#   Downloading pyarrow-0.17.1-cp38-cp38-win_amd64.whl (21.7 MB)
# Collecting azureml-dataprep<2.1.0a,>=2.0.1a
#   Downloading azureml_dataprep-2.0.6-py3-none-any.whl (28.2 MB)
# Requirement already satisfied, skipping upgrade: fusepy<4.0.0,>=3.0.1; extra == "fuse" in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-dataset-runtime[fuse]~=1.11.0->azureml-sdk[automl,explain,notebooks]) (3.0.1)
# Collecting azureml-automl-core~=1.11.0
#   Downloading azureml_automl_core-1.11.0-py3-none-any.whl (152 kB)
# Collecting azureml-telemetry~=1.11.0
#   Downloading azureml_telemetry-1.11.0-py3-none-any.whl (29 kB)
# Collecting azureml-train-core~=1.11.0
#   Downloading azureml_train_core-1.11.0-py3-none-any.whl (8.6 MB)
# Requirement already satisfied, skipping upgrade: ndg-httpsclient in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (0.5.1)
# Requirement already satisfied, skipping upgrade: azure-mgmt-authorization>=0.40.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (0.60.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-storage>=1.5.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (11.1.0)
# Requirement already satisfied, skipping upgrade: pytz in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (2020.1)
# Requirement already satisfied, skipping upgrade: jmespath in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (0.10.0)
# Requirement already satisfied, skipping upgrade: PyJWT in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (1.7.1)
# Requirement already satisfied, skipping upgrade: docker in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (4.2.2)
# Requirement already satisfied, skipping upgrade: contextlib2 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (0.6.0.post1)
# Requirement already satisfied, skipping upgrade: azure-mgmt-resource>=1.2.1 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (10.1.0)
# Requirement already satisfied, skipping upgrade: msrestazure>=0.4.33 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (0.6.4)
# Requirement already satisfied, skipping upgrade: azure-graphrbac>=0.40.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (0.61.1)
# Requirement already satisfied, skipping upgrade: adal>=1.2.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (1.2.4)
# Requirement already satisfied, skipping upgrade: urllib3>=1.23 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (1.25.9)
# Requirement already satisfied, skipping upgrade: pathspec in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (0.8.0)
# Requirement already satisfied, skipping upgrade: SecretStorage in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (3.1.2)
# Requirement already satisfied, skipping upgrade: jsonpickle in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (1.4.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (2.8.1)
# Requirement already satisfied, skipping upgrade: requests>=2.19.1 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (2.24.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-keyvault>=0.40.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (2.2.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-containerregistry>=2.0.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (2.8.0)
# Requirement already satisfied, skipping upgrade: msrest>=0.5.1 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (0.6.17)
# Collecting ruamel.yaml>=0.15.35
#   Using cached ruamel.yaml-0.16.10-py2.py3-none-any.whl (111 kB)
# Collecting backports.tempfile
#   Using cached backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied, skipping upgrade: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.* in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (2.9.2)
# Requirement already satisfied, skipping upgrade: pyopenssl in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (19.1.0)
# Requirement already satisfied, skipping upgrade: azure-common>=1.1.12 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (1.1.25)
# Collecting azureml-automl-runtime~=1.11.0
#   Downloading azureml_automl_runtime-1.11.0-py3-none-any.whl (1.9 MB)
# Collecting azureml-train-automl-runtime~=1.11.0
#   Downloading azureml_train_automl_runtime-1.11.0.post1-py3-none-any.whl (101 kB)
# Collecting azureml-interpret~=1.11.0
#   Downloading azureml_interpret-1.11.0-py3-none-any.whl (47 kB)
# Requirement already satisfied, skipping upgrade: ipython in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-contrib-notebook~=1.11.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (7.16.1)
# Requirement already satisfied, skipping upgrade: papermill<2 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-contrib-notebook~=1.11.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (1.2.1)
# Requirement already satisfied, skipping upgrade: ipykernel in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-contrib-notebook~=1.11.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (5.3.2)
# Requirement already satisfied, skipping upgrade: ipywidgets>=7.0.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-widgets~=1.11.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (7.5.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.14 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from pyarrow<1.0.0,>=0.17.0->azureml-dataset-runtime[fuse]~=1.11.0->azureml-sdk[automl,explain,notebooks]) (1.19.0)
# Requirement already satisfied, skipping upgrade: dotnetcore2<3.0.0,>=2.1.14 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-dataprep<2.1.0a,>=2.0.1a->azureml-dataset-runtime[fuse]~=1.11.0->azureml-sdk[automl,explain,notebooks]) (2.1.14)
# Requirement already satisfied, skipping upgrade: azure-identity<1.3.0,>=1.2.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-dataprep<2.1.0a,>=2.0.1a->azureml-dataset-runtime[fuse]~=1.11.0->azureml-sdk[automl,explain,notebooks]) (1.2.0)
# Collecting azureml-dataprep-native<21.0.0,>=20.0.2
#   Downloading azureml_dataprep_native-20.0.2-cp38-cp38-win_amd64.whl (7.8 MB)
# Requirement already satisfied, skipping upgrade: cloudpickle<2.0.0,>=1.1.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-dataprep<2.1.0a,>=2.0.1a->azureml-dataset-runtime[fuse]~=1.11.0->azureml-sdk[automl,explain,notebooks]) (1.5.0)
# Requirement already satisfied, skipping upgrade: applicationinsights in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from azureml-telemetry~=1.11.0->azureml-train-automl-client~=1.11.0->azureml-sdk[automl,explain,notebooks]) (0.11.9)
# Collecting azureml-train-restclients-hyperdrive~=1.11.0
#   Downloading azureml_train_restclients_hyperdrive-1.11.0-py3-none-any.whl (18 kB)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.1 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from ndg-httpsclient->azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (0.4.8)
# Requirement already satisfied, skipping upgrade: pypiwin32==223; sys_platform == "win32" and python_version >= "3.6" in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from docker->azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (223)
# Requirement already satisfied, skipping upgrade: six>=1.4.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from docker->azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (1.15.0)
# Requirement already satisfied, skipping upgrade: websocket-client>=0.32.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from docker->azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (0.57.0)
# Requirement already satisfied, skipping upgrade: jeepney>=0.4.2 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from SecretStorage->azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (0.4.3)
# Requirement already satisfied, skipping upgrade: importlib-metadata in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from jsonpickle->azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (1.7.0)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.19.1->azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.19.1->azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.19.1->azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (2020.6.20)
# Requirement already satisfied, skipping upgrade: isodate>=0.6.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from msrest>=0.5.1->azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (0.6.0)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.5.0 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from msrest>=0.5.1->azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (1.3.0)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Using cached ruamel.yaml.clib-0.2.0.tar.gz (178 kB)
# Collecting backports.weakref
#   Using cached backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied, skipping upgrade: cffi!=1.11.3,>=1.8 in c:\users\ryan\appdata\local\programs\python\python38\lib\site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.11.0->azureml-sdk[automl,explain,notebooks]) (1.14.0)
# Collecting pandas<=0.23.4,>=0.21.0
#   Downloading pandas-0.23.4.tar.gz (10.5 MB)
# ERROR: Could not find a version that satisfies the requirement onnxruntime==1.0.0 (from azureml-automl-runtime~=1.11.0->azureml-train-automl~=1.11.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (from versions: 1.2.0, 1.3.0, 1.4.0)
# ERROR: No matching distribution found for onnxruntime==1.0.0 (from azureml-automl-runtime~=1.11.0->azureml-train-automl~=1.11.0; extra == "automl"->azureml-sdk[automl,explain,notebooks])
# WARNING: You are using pip version 20.2; however, version 20.2.2 is available.
# You should consider upgrading via the 'c:\users\ryan\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ## Connect to Your Workspace
#
# Now connect to your workspace using the Azure ML SDK.
#
# > **Note**: You may be prompted to authenticate. Just copy the code and click the link provided to sign into your Azure subscription, and then return to this notebook.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.9.0 to work with ms-learn-ml

# %% [markdown]
# ## Train and Register a Model
#
# Now run the cell below to train and register a model.

# %%
from azureml.core import Experiment
from azureml.core import Model
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# Create an Azure ML experiment in your workspace
experiment = Experiment(workspace = ws, name = "diabetes-training")
run = experiment.start_logging()
print("Starting experiment:", experiment.name)

# load the diabetes dataset
print("Loading Data...")
diabetes = pd.read_csv('data/diabetes.csv')

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train a decision tree model
print('Training a decision tree model')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# Save the trained model
model_file = 'diabetes_model.pkl'
joblib.dump(value=model, filename=model_file)
run.upload_file(name = 'outputs/' + model_file, path_or_stream = './' + model_file)

# Complete the run
run.complete()

# Register the model
run.register_model(model_path='outputs/diabetes_model.pkl', model_name='diabetes_model',
                   tags={'Training context':'Inline Training'},
                   properties={'AUC': run.get_metrics()['AUC'], 'Accuracy': run.get_metrics()['Accuracy']})

print('Model trained and registered.')
# Out:
# Starting experiment: diabetes-training
# Loading Data...
# Training a decision tree model
# Accuracy: 0.8866666666666667
# AUC: 0.8733718095427634
# Model trained and registered.

# %% [markdown]
# ## Generate and Upload Batch Data
#
# Since we don't actually have a fully staffed clinic with patients from whom to get new data for this course, you'll generate a random sample from our diabetes CSV file and use those to test the pipeline. Then you'll upload that data to a datastore in the Azure Machine Learning workspace and register a dataset for it.

# %%
from azureml.core import Datastore, Dataset
import pandas as pd
import os

# Load the diabetes data
diabetes = pd.read_csv('data/diabetes2.csv')
# Get a 100-item sample of the feature columns (not the diabetic label)
sample = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].sample(n=100).values

# Create a folder
batch_folder = './batch-data'
os.makedirs(batch_folder, exist_ok=True)
print("Folder created!")

# Save each sample as a separate file
print("Saving files...")
for i in range(100):
    fname = str(i+1) + '.csv'
    sample[i].tofile(os.path.join(batch_folder, fname), sep=",")
print("files saved!")

# Upload the files to the default datastore
print("Uploading files to datastore...")
default_ds = ws.get_default_datastore()
default_ds.upload(src_dir="batch-data", target_path="batch-data", overwrite=True, show_progress=True)

# Register a dataset for the input data
batch_data_set = Dataset.File.from_files(path=(default_ds, 'batch-data/'), validate=False)
try:
    batch_data_set = batch_data_set.register(workspace=ws, 
                                             name='batch-data',
                                             description='batch data',
                                             create_new_version=True)
except Exception as ex:
    print(ex)

print("Done!")
# Out:
# Folder created!
# Saving files...
# files saved!
# Uploading files to datastore...
# Uploading an estimated of 100 files
# Uploading batch-data\1.csv
# Uploading batch-data\10.csv
# Uploading batch-data\100.csv
# Uploading batch-data\11.csv
# Uploading batch-data\12.csv
# Uploading batch-data\13.csv
# Uploading batch-data\14.csv
# Uploading batch-data\15.csv
# Uploading batch-data\16.csv
# Uploading batch-data\17.csv
# Uploading batch-data\18.csv
# Uploading batch-data\19.csv
# Uploading batch-data\2.csv
# Uploading batch-data\20.csv
# Uploading batch-data\21.csv
# Uploading batch-data\22.csv
# Uploading batch-data\23.csv
# Uploading batch-data\24.csv
# Uploading batch-data\25.csv
# Uploading batch-data\26.csv
# Uploading batch-data\27.csv
# Uploading batch-data\28.csv
# Uploading batch-data\29.csv
# Uploading batch-data\3.csv
# Uploading batch-data\30.csv
# Uploading batch-data\31.csv
# Uploading batch-data\32.csv
# Uploading batch-data\33.csv
# Uploading batch-data\34.csv
# Uploading batch-data\35.csv
# Uploading batch-data\36.csv
# Uploading batch-data\37.csv
# Uploaded batch-data\25.csv, 1 files out of an estimated total of 100
# Uploaded batch-data\27.csv, 2 files out of an estimated total of 100
# Uploading batch-data\38.csv
# Uploading batch-data\39.csv
# Uploaded batch-data\15.csv, 3 files out of an estimated total of 100
# Uploading batch-data\4.csv
# Uploaded batch-data\16.csv, 4 files out of an estimated total of 100
# Uploaded batch-data\14.csv, 5 files out of an estimated total of 100
# Uploading batch-data\40.csv
# Uploading batch-data\41.csv
# Uploaded batch-data\37.csv, 6 files out of an estimated total of 100
# Uploading batch-data\42.csv
# Uploaded batch-data\3.csv, 7 files out of an estimated total of 100
# Uploading batch-data\43.csv
# Uploaded batch-data\1.csv, 8 files out of an estimated total of 100
# Uploading batch-data\44.csv
# Uploaded batch-data\20.csv, 9 files out of an estimated total of 100
# Uploading batch-data\45.csv
# Uploaded batch-data\32.csv, 10 files out of an estimated total of 100
# Uploaded batch-data\24.csv, 11 files out of an estimated total of 100
# Uploading batch-data\46.csv
# Uploaded batch-data\34.csv, 12 files out of an estimated total of 100
# Uploading batch-data\47.csv
# Uploading batch-data\48.csv
# Uploaded batch-data\33.csv, 13 files out of an estimated total of 100
# Uploaded batch-data\30.csv, 14 files out of an estimated total of 100
# Uploading batch-data\49.csv
# Uploading batch-data\5.csv
# Uploaded batch-data\19.csv, 15 files out of an estimated total of 100
# Uploading batch-data\50.csv
# Uploaded batch-data\35.csv, 16 files out of an estimated total of 100
# Uploading batch-data\51.csv
# Uploaded batch-data\21.csv, 17 files out of an estimated total of 100
# Uploading batch-data\52.csv
# Uploaded batch-data\18.csv, 18 files out of an estimated total of 100
# Uploading batch-data\53.csv
# Uploaded batch-data\11.csv, 19 files out of an estimated total of 100
# Uploaded batch-data\17.csv, 20 files out of an estimated total of 100
# Uploading batch-data\54.csv
# Uploaded batch-data\23.csv, 21 files out of an estimated total of 100
# Uploading batch-data\55.csv
# Uploading batch-data\56.csv
# Uploaded batch-data\13.csv, 22 files out of an estimated total of 100
# Uploaded batch-data\38.csv, 23 files out of an estimated total of 100
# Uploading batch-data\57.csv
# Uploaded batch-data\4.csv, 24 files out of an estimated total of 100
# Uploading batch-data\58.csv
# Uploading batch-data\59.csv
# Uploaded batch-data\29.csv, 25 files out of an estimated total of 100
# Uploading batch-data\6.csv
# Uploaded batch-data\39.csv, 26 files out of an estimated total of 100
# Uploading batch-data\60.csv
# Uploaded batch-data\22.csv, 27 files out of an estimated total of 100
# Uploading batch-data\61.csv
# Uploaded batch-data\26.csv, 28 files out of an estimated total of 100
# Uploading batch-data\62.csv
# Uploaded batch-data\36.csv, 29 files out of an estimated total of 100
# Uploaded batch-data\2.csv, 30 files out of an estimated total of 100
# Uploading batch-data\63.csv
# Uploading batch-data\64.csv
# Uploaded batch-data\31.csv, 31 files out of an estimated total of 100
# Uploading batch-data\65.csv
# Uploaded batch-data\41.csv, 32 files out of an estimated total of 100
# Uploading batch-data\66.csv
# Uploaded batch-data\42.csv, 33 files out of an estimated total of 100
# Uploaded batch-data\43.csv, 34 files out of an estimated total of 100
# Uploading batch-data\67.csv
# Uploading batch-data\68.csv
# Uploaded batch-data\44.csv, 35 files out of an estimated total of 100
# Uploading batch-data\69.csv
# Uploaded batch-data\45.csv, 36 files out of an estimated total of 100
# Uploading batch-data\7.csv
# Uploaded batch-data\46.csv, 37 files out of an estimated total of 100
# Uploading batch-data\70.csv
# Uploaded batch-data\47.csv, 38 files out of an estimated total of 100
# Uploading batch-data\71.csv
# Uploaded batch-data\40.csv, 39 files out of an estimated total of 100
# Uploaded batch-data\5.csv, 40 files out of an estimated total of 100
# Uploading batch-data\72.csv
# Uploaded batch-data\50.csv, 41 files out of an estimated total of 100
# Uploading batch-data\73.csv
# Uploading batch-data\74.csv
# Uploaded batch-data\48.csv, 42 files out of an estimated total of 100
# Uploading batch-data\75.csv
# Uploaded batch-data\49.csv, 43 files out of an estimated total of 100
# Uploading batch-data\76.csv
# Uploaded batch-data\51.csv, 44 files out of an estimated total of 100
# Uploading batch-data\77.csv
# Uploaded batch-data\52.csv, 45 files out of an estimated total of 100
# Uploaded batch-data\53.csv, 46 files out of an estimated total of 100
# Uploading batch-data\78.csv
# Uploaded batch-data\56.csv, 47 files out of an estimated total of 100
# Uploading batch-data\79.csv
# Uploading batch-data\8.csv
# Uploaded batch-data\54.csv, 48 files out of an estimated total of 100
# Uploading batch-data\80.csv
# Uploaded batch-data\55.csv, 49 files out of an estimated total of 100
# Uploading batch-data\81.csv
# Uploaded batch-data\57.csv, 50 files out of an estimated total of 100
# Uploading batch-data\82.csv
# Uploaded batch-data\6.csv, 51 files out of an estimated total of 100
# Uploading batch-data\83.csv
# Uploaded batch-data\59.csv, 52 files out of an estimated total of 100
# Uploading batch-data\84.csv
# Uploaded batch-data\58.csv, 53 files out of an estimated total of 100
# Uploading batch-data\85.csv
# Uploaded batch-data\60.csv, 54 files out of an estimated total of 100
# Uploading batch-data\86.csv
# Uploaded batch-data\61.csv, 55 files out of an estimated total of 100
# Uploading batch-data\87.csv
# Uploaded batch-data\10.csv, 56 files out of an estimated total of 100
# Uploading batch-data\88.csv
# Uploaded batch-data\62.csv, 57 files out of an estimated total of 100
# Uploading batch-data\89.csv
# Uploaded batch-data\64.csv, 58 files out of an estimated total of 100
# Uploaded batch-data\63.csv, 59 files out of an estimated total of 100
# Uploaded batch-data\12.csv, 60 files out of an estimated total of 100
# Uploading batch-data\9.csv
# Uploading batch-data\90.csv
# Uploading batch-data\91.csv
# Uploaded batch-data\65.csv, 61 files out of an estimated total of 100
# Uploaded batch-data\66.csv, 62 files out of an estimated total of 100
# Uploading batch-data\92.csv
# Uploading batch-data\93.csv
# Uploaded batch-data\67.csv, 63 files out of an estimated total of 100
# Uploading batch-data\94.csv
# Uploaded batch-data\7.csv, 64 files out of an estimated total of 100
# Uploading batch-data\95.csv
# Uploaded batch-data\68.csv, 65 files out of an estimated total of 100
# Uploading batch-data\96.csv
# Uploaded batch-data\69.csv, 66 files out of an estimated total of 100
# Uploading batch-data\97.csv
# Uploaded batch-data\71.csv, 67 files out of an estimated total of 100
# Uploaded batch-data\73.csv, 68 files out of an estimated total of 100
# Uploaded batch-data\74.csv, 69 files out of an estimated total of 100
# Uploading batch-data\98.csv
# Uploading batch-data\99.csv
# Uploaded batch-data\70.csv, 70 files out of an estimated total of 100
# Uploaded batch-data\72.csv, 71 files out of an estimated total of 100
# Uploaded batch-data\100.csv, 72 files out of an estimated total of 100
# Uploaded batch-data\76.csv, 73 files out of an estimated total of 100
# Uploaded batch-data\28.csv, 74 files out of an estimated total of 100
# Uploaded batch-data\77.csv, 75 files out of an estimated total of 100
# Uploaded batch-data\75.csv, 76 files out of an estimated total of 100
# Uploaded batch-data\79.csv, 77 files out of an estimated total of 100
# Uploaded batch-data\78.csv, 78 files out of an estimated total of 100
# Uploaded batch-data\8.csv, 79 files out of an estimated total of 100
# Uploaded batch-data\86.csv, 80 files out of an estimated total of 100
# Uploaded batch-data\80.csv, 81 files out of an estimated total of 100
# Uploaded batch-data\82.csv, 82 files out of an estimated total of 100
# Uploaded batch-data\81.csv, 83 files out of an estimated total of 100
# Uploaded batch-data\83.csv, 84 files out of an estimated total of 100
# Uploaded batch-data\85.csv, 85 files out of an estimated total of 100
# Uploaded batch-data\89.csv, 86 files out of an estimated total of 100
# Uploaded batch-data\84.csv, 87 files out of an estimated total of 100
# Uploaded batch-data\88.csv, 88 files out of an estimated total of 100
# Uploaded batch-data\9.csv, 89 files out of an estimated total of 100
# Uploaded batch-data\91.csv, 90 files out of an estimated total of 100
# Uploaded batch-data\90.csv, 91 files out of an estimated total of 100
# Uploaded batch-data\87.csv, 92 files out of an estimated total of 100
# Uploaded batch-data\92.csv, 93 files out of an estimated total of 100
# Uploaded batch-data\94.csv, 94 files out of an estimated total of 100
# Uploaded batch-data\93.csv, 95 files out of an estimated total of 100
# Uploaded batch-data\95.csv, 96 files out of an estimated total of 100
# Uploaded batch-data\99.csv, 97 files out of an estimated total of 100
# Uploaded batch-data\96.csv, 98 files out of an estimated total of 100
# Uploaded batch-data\98.csv, 99 files out of an estimated total of 100
# Uploaded batch-data\97.csv, 100 files out of an estimated total of 100
# Uploaded 100 files
# Done!

# %% [markdown]
# ## Create Compute
#
# We'll need a compute context for the pipeline, so we'll create an Azure Machine Learning compute cluster in your workspace (or use an existing one if you have created it previously).
#
# > **Important**: Change *your-compute-cluster* to the unique name for your compute cluster in the code below before running it!

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "ms-learn-CCryan"

# Check for existing cluster
try:
    inference_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # Create an AzureMl Compute resource
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS2_V2', max_nodes=2)
    inference_cluster = ComputeTarget.create(ws, cluster_name, compute_config)

inference_cluster.wait_for_completion(show_output=True)
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Create a Pipeline for Batch Inferencing
#
# Now we're ready to define the pipeline we'll use for batch inferencing. Our pipeline will need Python code to perform the batch inferencing, so let's create a folder where we can keep all the files used by the pipeline:

# %%
import os
# Create a folder for the experiment files
experiment_folder = 'batch_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# batch_pipeline

# %% [markdown]
# Now we'll create a Python script to do the actual work, and save it in the pipeline folder:

# %%
# %%writefile $experiment_folder/batch_diabetes.py
import os
import numpy as np
from azureml.core import Model
import joblib


def init():
    # Runs when the pipeline step is initialized
    global model

    # load the model
    model_path = Model.get_model_path('diabetes_model')
    model = joblib.load(model_path)


def run(mini_batch):
    # This runs for each batch
    resultList = []

    # process each file in the batch
    for f in mini_batch:
        # Read the comma-delimited data into an array
        data = np.genfromtxt(f, delimiter=',')
        # Reshape into a 2-dimensional array for prediction (model expects multiple items)
        prediction = model.predict(data.reshape(1, -1))
        # Append prediction to results
        resultList.append("{}: {}".format(os.path.basename(f), prediction[0]))
    return resultList
# Out:
# Writing batch_pipeline/batch_diabetes.py

# %% [markdown]
# Next we'll define a run context that includes the dependencies required by the script

# %%
from azureml.core import Environment
from azureml.core.runconfig import DEFAULT_CPU_IMAGE
from azureml.core.runconfig import CondaDependencies

# Add dependencies required by the model
# For scikit-learn models, you need scikit-learn
# For parallel pipeline steps, you need azureml-core and azureml-dataprep[fuse]
cd = CondaDependencies.create(pip_packages=['scikit-learn','azureml-defaults','azureml-core','azureml-dataprep[fuse]'])

batch_env = Environment(name='batch_environment')
batch_env.python.conda_dependencies = cd
batch_env.docker.enabled = True
batch_env.docker.base_image = DEFAULT_CPU_IMAGE
print('Configuration ready.')
# Out:
# Configuration ready.

# %% [markdown]
# You're going to use a pipeline to run the batch prediction script, generate predictions from the input data, and save the results as a text file in the output folder. To do this, you can use a **ParallelRunStep**, which enables the batch data to be processed in parallel and the results collated in a single output file named *parallel_run_step.txt*.

# %%
from azureml.pipeline.steps import ParallelRunConfig, ParallelRunStep
from azureml.pipeline.core import PipelineData

default_ds = ws.get_default_datastore()

output_dir = PipelineData(name='inferences', 
                          datastore=default_ds, 
                          output_path_on_compute='diabetes/results')

parallel_run_config = ParallelRunConfig(
    source_directory=experiment_folder,
    entry_script="batch_diabetes.py",
    mini_batch_size="5",
    error_threshold=10,
    output_action="append_row",
    environment=batch_env,
    compute_target=inference_cluster,
    node_count=2)

parallelrun_step = ParallelRunStep(
    name='batch-score-diabetes',
    parallel_run_config=parallel_run_config,
    inputs=[batch_data_set.as_named_input('diabetes_batch')],
    output=output_dir,
    arguments=[],
    allow_reuse=True
)

print('Steps defined')
# Out:
# Steps defined

# %% [markdown]
# Now it's time to put the step into a pipeline, and run it.
#
# > **Note**: This may take some time!

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

pipeline = Pipeline(workspace=ws, steps=[parallelrun_step])
pipeline_run = Experiment(ws, 'batch_prediction_pipeline').submit(pipeline)
print('Running pipeline...')
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step batch-score-diabetes [b448b36b][8a749328-b56a-420f-b4ec-90d3e0452437], (This step will run and generate new outputs)
# Created data reference diabetes_batch_0 for StepId [249a9d42][606f3237-b201-42f2-9bb9-0d49b0db1dc8], (Consumers of this data will generate new runs.)
# Submitted PipelineRun d462eca3-a5e1-41ae-a27b-56261b3f03f4
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/batch_prediction_pipeline/runs/d462eca3-a5e1-41ae-a27b-56261b3f03f4?wsid=/subscriptions/375be063-544d-4b99-aed9-5a0e16b1f428/resourcegroups/ms-learn-ml/workspaces/ms-learn-ml
# Running pipeline...
# PipelineRunId: d462eca3-a5e1-41ae-a27b-56261b3f03f4
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/batch_prediction_pipeline/runs/d462eca3-a5e1-41ae-a27b-56261b3f03f4?wsid=/subscriptions/375be063-544d-4b99-aed9-5a0e16b1f428/resourcegroups/ms-learn-ml/workspaces/ms-learn-ml
# PipelineRun Status: Running
#
#
# StepRunId: 55a549b7-5d3b-49b4-bdc4-1391d5152d90
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/batch_prediction_pipeline/runs/55a549b7-5d3b-49b4-bdc4-1391d5152d90?wsid=/subscriptions/375be063-544d-4b99-aed9-5a0e16b1f428/resourcegroups/ms-learn-ml/workspaces/ms-learn-ml
# StepRun( batch-score-diabetes ) Status: NotStarted
# StepRun( batch-score-diabetes ) Status: Queued
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# StepRun( batch-score-diabetes ) Status: Running
# 2020/08/16 07:35:10 Downloading source code...
# 2020/08/16 07:35:11 Finished downloading source code
# 2020/08/16 07:35:12 Creating Docker network: acb_default_network, driver: 'bridge'
# 2020/08/16 07:35:12 Successfully set up Docker network: acb_default_network
# 2020/08/16 07:35:12 Setting up Docker configuration...
# 2020/08/16 07:35:13 Successfully set up Docker configuration
# 2020/08/16 07:35:13 Logging in to registry: b1533106f06a49c8a9a7078ce1e0e1a3.azurecr.io
# 2020/08/16 07:35:14 Successfully logged into b1533106f06a49c8a9a7078ce1e0e1a3.azurecr.io
# 2020/08/16 07:35:14 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/08/16 07:35:14 Scanning for dependencies...
# 2020/08/16 07:35:15 Successfully scanned dependencies
# 2020/08/16 07:35:15 Launching container with name: acb_step_0
# Sending build context to Docker daemon  60.93kB
#
# Step 1/15 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200423.v1@sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d
# sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# fe703b657a32: Pulling fs layer
# f9df1fafd224: Pulling fs layer
# a645a4b887f9: Pulling fs layer
# 57db7fe0b522: Pulling fs layer
# 20b5fabe4f63: Pulling fs layer
# 22898513a7dc: Pulling fs layer
# b77f65fcd9d7: Pulling fs layer
# 132ebd5cd5ca: Pulling fs layer
# 01991399be72: Pulling fs layer
# 60c58ca14ef7: Pulling fs layer
# ca339bb1ce1b: Pulling fs layer
# 57db7fe0b522: Waiting
# 20b5fabe4f63: Waiting
# 22898513a7dc: Waiting
# b77f65fcd9d7: Waiting
# 132ebd5cd5ca: Waiting
# 01991399be72: Waiting
# 60c58ca14ef7: Waiting
# ca339bb1ce1b: Waiting
# f9df1fafd224: Download complete
# a645a4b887f9: Download complete
# 57db7fe0b522: Verifying Checksum
# 57db7fe0b522: Download complete
# fe703b657a32: Verifying Checksum
# fe703b657a32: Download complete
# 22898513a7dc: Verifying Checksum
# 22898513a7dc: Download complete
# b77f65fcd9d7: Verifying Checksum
# b77f65fcd9d7: Download complete
# 20b5fabe4f63: Verifying Checksum
# 20b5fabe4f63: Download complete
# 60c58ca14ef7: Verifying Checksum
# 60c58ca14ef7: Download complete
# 132ebd5cd5ca: Verifying Checksum
# 132ebd5cd5ca: Download complete
# ca339bb1ce1b: Verifying Checksum
# ca339bb1ce1b: Download complete
# 01991399be72: Verifying Checksum
# 01991399be72: Download complete
# fe703b657a32: Pull complete
# f9df1fafd224: Pull complete
# a645a4b887f9: Pull complete
# 57db7fe0b522: Pull complete
# 20b5fabe4f63: Pull complete
# 22898513a7dc: Pull complete
# b77f65fcd9d7: Pull complete
# 132ebd5cd5ca: Pull complete
# 01991399be72: Pull complete
# 60c58ca14ef7: Pull complete
# ca339bb1ce1b: Pull complete
# Digest: sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200423.v1@sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d
#  ---> a0dab4f7c804
# Step 2/15 : USER root
#  ---> Running in a6a46922181d
# Removing intermediate container a6a46922181d
#  ---> 65b4d4a393e7
# Step 3/15 : RUN mkdir -p $HOME/.cache
#  ---> Running in 7efb15c0b2d1
# Removing intermediate container 7efb15c0b2d1
#  ---> b8c8ebf862db
# Step 4/15 : WORKDIR /
#  ---> Running in 1ae4b970c0b0
# Removing intermediate container 1ae4b970c0b0
#  ---> 8fbf19356c40
# Step 5/15 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> d2011d163d71
# Step 6/15 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in aa9977ab6db2
# Removing intermediate container aa9977ab6db2
#  ---> 828549a189cc
# Step 7/15 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 9aee77548cdf
# Step 8/15 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_038971e8daecf4b45640448e5bd2c009 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in c5bff7fea0bf
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# libffi-3.2.1         | 43 KB     |            |   0%
# libffi-3.2.1         | 43 KB     | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | #######3   |  73%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# pip-20.2.2           | 2.0 MB    |            |   0%
# pip-20.2.2           | 2.0 MB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ##         |  21%
# python-3.6.2         | 27.0 MB   | #####      |  50%
# python-3.6.2         | 27.0 MB   | ########   |  81%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# ca-certificates-2020 | 133 KB    |            |   0%
# ca-certificates-2020 | 133 KB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# setuptools-49.6.0    | 927 KB    |            |   0%
# setuptools-49.6.0    | 927 KB    | ########## | 100%
#
# wheel-0.34.2         | 49 KB     |            |   0%
# wheel-0.34.2         | 49 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_038971e8daecf4b45640448e5bd2c009/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv._x2rbn85.requirements.txt']
# Pip subprocess output:
# Collecting scikit-learn
#   Downloading scikit_learn-0.23.2-cp36-cp36m-manylinux1_x86_64.whl (6.8 MB)
# Collecting azureml-defaults~=1.9.0
#   Downloading azureml_defaults-1.9.0-py3-none-any.whl (3.0 kB)
# Collecting azureml-core~=1.9.0
#   Downloading azureml_core-1.9.0-py3-none-any.whl (1.5 MB)
# Collecting azureml-dataprep[fuse]
#   Downloading azureml_dataprep-2.0.6-py3-none-any.whl (28.2 MB)
# Collecting scipy>=0.19.1
#   Downloading scipy-1.5.2-cp36-cp36m-manylinux1_x86_64.whl (25.9 MB)
# Collecting joblib>=0.11
#   Downloading joblib-0.16.0-py3-none-any.whl (300 kB)
# Collecting numpy>=1.13.3
#   Downloading numpy-1.19.1-cp36-cp36m-manylinux2010_x86_64.whl (14.5 MB)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting werkzeug==0.16.1
#   Downloading Werkzeug-0.16.1-py2.py3-none-any.whl (327 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting azure-mgmt-network~=10.0
#   Downloading azure_mgmt_network-10.2.0-py2.py3-none-any.whl (8.6 MB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting azure-graphrbac>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting requests>=2.19.1
#   Downloading requests-2.24.0-py2.py3-none-any.whl (61 kB)
# Collecting pyopenssl
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.25-py2.py3-none-any.whl (12 kB)
# Collecting azure-mgmt-resource>=1.2.1
#   Downloading azure_mgmt_resource-10.2.0-py2.py3-none-any.whl (968 kB)
# Collecting azure-mgmt-storage>=1.5.0
#   Downloading azure_mgmt_storage-11.1.0-py2.py3-none-any.whl (547 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.4.1-py2.py3-none-any.whl (36 kB)
# Collecting docker
#   Downloading docker-4.3.0-py2.py3-none-any.whl (145 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.25.10-py2.py3-none-any.whl (127 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.1.2-py3-none-any.whl (14 kB)
# Collecting PyJWT
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting pytz
#   Downloading pytz-2020.1-py2.py3-none-any.whl (510 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.18-py2.py3-none-any.whl (84 kB)
# Collecting python-dateutil>=2.7.3
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-3.0-cp35-abi3-manylinux2010_x86_64.whl (2.7 MB)
# Collecting azure-mgmt-keyvault>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting azure-mgmt-authorization>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.4-py2.py3-none-any.whl (55 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.0-py2.py3-none-any.whl (28 kB)
# Collecting ruamel.yaml>0.16.7
#   Downloading ruamel.yaml-0.16.10-py2.py3-none-any.whl (111 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.14-py3-none-manylinux1_x86_64.whl (29.3 MB)
# Collecting azure-identity<1.3.0,>=1.2.0
#   Downloading azure_identity-1.2.0-py2.py3-none-any.whl (58 kB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.5.0-py3-none-any.whl (22 kB)
# Collecting azureml-dataprep-native<21.0.0,>=20.0.2
#   Downloading azureml_dataprep_native-20.0.2-cp36-cp36m-manylinux1_x86_64.whl (10.7 MB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.2.zip (177 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.4.0.tar.gz (15 kB)
# Collecting pandas>=0.20.2
#   Downloading pandas-1.1.0-cp36-cp36m-manylinux1_x86_64.whl (10.5 MB)
# Collecting six>=1.10
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_038971e8daecf4b45640448e5bd2c009/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core~=1.9.0->-r /azureml-environment-setup/condaenv._x2rbn85.requirements.txt (line 3)) (2020.6.20)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-1.7.0-py2.py3-none-any.whl (31 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.4.3-py3-none-any.whl (21 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting cffi!=1.11.3,>=1.8
#   Downloading cffi-1.14.2-cp36-cp36m-manylinux1_x86_64.whl (400 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.0-cp36-cp36m-manylinux1_x86_64.whl (548 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.8.0-py2.py3-none-any.whl (121 kB)
# Collecting msal-extensions~=0.1.3
#   Downloading msal_extensions-0.1.3-py2.py3-none-any.whl (9.0 kB)
# Collecting msal<2.0.0,>=1.0.0
#   Downloading msal-1.4.3-py2.py3-none-any.whl (49 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (27 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.1.0-py3-none-any.whl (4.9 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: json-logging-py, fusepy, dill, liac-arff
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3923 sha256=e5074244c5e7e1fe49352dd09e0079612b545662a538f4ab0e8b229479cc3f7a
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10503 sha256=6574c52c2549025160f9c8a41d288318c84145229d28a27a4aa76501a8dae934
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.2-py3-none-any.whl size=78912 sha256=ae0accb0859763d11e6d5abb0ad40eb22a04fc2fb16af4e1dfe683b469e3fe35
#   Stored in directory: /root/.cache/pip/wheels/02/49/cf/660924cd9bc5fcddc3a0246fe39800c83028d3ccea244de352
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.4.0-py3-none-any.whl size=13333 sha256=1e44eaf887fc0d74987844983b03269e2997c175bc4690076453b7e59520b10b
#   Stored in directory: /root/.cache/pip/wheels/ba/2a/e1/6f7be2e2ea150e2486bff64fd6f0670f4f35f4c8f31c819fb8
# Successfully built json-logging-py fusepy dill liac-arff
# Installing collected packages: numpy, scipy, joblib, threadpoolctl, scikit-learn, MarkupSafe, Jinja2, click, werkzeug, itsdangerous, flask, gunicorn, json-logging-py, applicationinsights, configparser, six, pycparser, cffi, cryptography, urllib3, idna, chardet, requests, PyJWT, python-dateutil, adal, oauthlib, requests-oauthlib, isodate, msrest, msrestazure, azure-common, azure-mgmt-network, contextlib2, azure-graphrbac, backports.weakref, backports.tempfile, pyopenssl, azure-mgmt-resource, azure-mgmt-storage, zipp, importlib-metadata, jsonpickle, websocket-client, docker, jmespath, jeepney, SecretStorage, pytz, pyasn1, ndg-httpsclient, azure-mgmt-keyvault, azure-mgmt-authorization, azure-mgmt-containerregistry, pathspec, ruamel.yaml.clib, ruamel.yaml, azureml-core, dill, liac-arff, pandas, azureml-model-management-sdk, distro, dotnetcore2, azure-core, msal, portalocker, msal-extensions, azure-identity, cloudpickle, azureml-dataprep-native, fusepy, azureml-dataprep, azureml-defaults
# Successfully installed Jinja2-2.11.2 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.1.2 adal-1.2.4 applicationinsights-0.11.9 azure-common-1.1.25 azure-core-1.8.0 azure-graphrbac-0.61.1 azure-identity-1.2.0 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-network-10.2.0 azure-mgmt-resource-10.2.0 azure-mgmt-storage-11.1.0 azureml-core-1.9.0 azureml-dataprep-2.0.6 azureml-dataprep-native-20.0.2 azureml-defaults-1.9.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.2 chardet-3.0.4 click-7.1.2 cloudpickle-1.5.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.0 dill-0.3.2 distro-1.5.0 docker-4.3.0 dotnetcore2-2.1.14 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-1.7.0 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.4.3 jmespath-0.10.0 joblib-0.16.0 json-logging-py-0.2 jsonpickle-1.4.1 liac-arff-2.4.0 msal-1.4.3 msal-extensions-0.1.3 msrest-0.6.18 msrestazure-0.6.4 ndg-httpsclient-0.5.1 numpy-1.19.1 oauthlib-3.1.0 pandas-1.1.0 pathspec-0.8.0 portalocker-1.7.1 pyasn1-0.4.8 pycparser-2.20 pyopenssl-19.1.0 python-dateutil-2.8.1 pytz-2020.1 requests-2.24.0 requests-oauthlib-1.3.0 ruamel.yaml-0.16.10 ruamel.yaml.clib-0.2.0 scikit-learn-0.23.2 scipy-1.5.2 six-1.15.0 threadpoolctl-2.1.0 urllib3-1.25.10 websocket-client-0.57.0 werkzeug-0.16.1 zipp-3.1.0
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.8.4
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_038971e8daecf4b45640448e5bd2c009
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container c5bff7fea0bf
#  ---> 783e8ba36516
# Step 9/15 : ENV PATH /azureml-envs/azureml_038971e8daecf4b45640448e5bd2c009/bin:$PATH
#  ---> Running in fcb30976bc37
# Removing intermediate container fcb30976bc37
#  ---> 8a69cf8a5405
# Step 10/15 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_038971e8daecf4b45640448e5bd2c009
#  ---> Running in c2e75854f504
# Removing intermediate container c2e75854f504
#  ---> 11aebeb17431
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_038971e8daecf4b45640448e5bd2c009/lib:$LD_LIBRARY_PATH
#  ---> Running in feed88cfbf6f
# Removing intermediate container feed88cfbf6f
#  ---> d637dbccb2f1
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> d2ed0d4229b2
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 28cbd0cdef51
# Removing intermediate container 28cbd0cdef51
#  ---> 584b03105461
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in ad9da5acf9de
# Removing intermediate container ad9da5acf9de
#  ---> 36a53b78cec0
# Step 15/15 : CMD ["bash"]
#  ---> Running in 3e42d74c8413
# Removing intermediate container 3e42d74c8413
#  ---> 5a19901ed0fe
# Successfully built 5a19901ed0fe
# Successfully tagged b1533106f06a49c8a9a7078ce1e0e1a3.azurecr.io/azureml/azureml_87923348625dfb0a03e592d7635ea9b9:latest
# 2020/08/16 07:37:46 Successfully executed container: acb_step_0
# 2020/08/16 07:37:46 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/08/16 07:37:46 Pushing image: b1533106f06a49c8a9a7078ce1e0e1a3.azurecr.io/azureml/azureml_87923348625dfb0a03e592d7635ea9b9:latest, attempt 1
# The push refers to repository [b1533106f06a49c8a9a7078ce1e0e1a3.azurecr.io/azureml/azureml_87923348625dfb0a03e592d7635ea9b9]
# e9eb445dbbc9: Preparing
# e5c2f4971c48: Preparing
# 55b58a013c1a: Preparing
# 69d89ba7f922: Preparing
# b8524a0926db: Preparing
# b26d99803388: Preparing
# f5aa53607bc1: Preparing
# 07eae5ad8c0b: Preparing
# facf43cddd83: Preparing
# 69a9bdc813b0: Preparing
# 7e2b9752143f: Preparing
# 63a67842a4c7: Preparing
# ae3a847dbd6b: Preparing
# 4ae3adcb66cb: Preparing
# aa6685385151: Preparing
# 0040d8f00d7e: Preparing
# 9e6f810a2aab: Preparing
# 7e2b9752143f: Waiting
# 63a67842a4c7: Waiting
# ae3a847dbd6b: Waiting
# b26d99803388: Waiting
# f5aa53607bc1: Waiting
# 4ae3adcb66cb: Waiting
# aa6685385151: Waiting
# 0040d8f00d7e: Waiting
# 07eae5ad8c0b: Waiting
# facf43cddd83: Waiting
# 9e6f810a2aab: Waiting
# 69a9bdc813b0: Waiting
# e9eb445dbbc9: Pushed
# b8524a0926db: Pushed
# 69d89ba7f922: Pushed
# 55b58a013c1a: Pushed
# b26d99803388: Pushed
# f5aa53607bc1: Pushed
# 07eae5ad8c0b: Pushed
#
# 69a9bdc813b0: Pushed
# 63a67842a4c7: Pushed
# 4ae3adcb66cb: Pushed
# 7e2b9752143f: Pushed
# aa6685385151: Pushed
# 0040d8f00d7e: Pushed
# facf43cddd83: Pushed
# ae3a847dbd6b: Pushed
# 9e6f810a2aab: Pushed
# e5c2f4971c48: Pushed
# latest: digest: sha256:9d01663ab714bbf374dab10858c1b3aefb80935e09ad9070aa83cb9dc1b3d4a4 size: 3883
# 2020/08/16 07:39:08 Successfully pushed image: b1533106f06a49c8a9a7078ce1e0e1a3.azurecr.io/azureml/azureml_87923348625dfb0a03e592d7635ea9b9:latest
# 2020/08/16 07:39:08 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 151.617304)
# 2020/08/16 07:39:08 Populating digests for step ID: acb_step_0...
# 2020/08/16 07:39:09 Successfully populated digests for step ID: acb_step_0
# 2020/08/16 07:39:09 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 82.015689)
# 2020/08/16 07:39:09 The following dependencies were found:
# 2020/08/16 07:39:09
# - image:
#     registry: b1533106f06a49c8a9a7078ce1e0e1a3.azurecr.io
#     repository: azureml/azureml_87923348625dfb0a03e592d7635ea9b9
#     tag: latest
#     digest: sha256:9d01663ab714bbf374dab10858c1b3aefb80935e09ad9070aa83cb9dc1b3d4a4
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20200423.v1
#     digest: sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d
#   git: {}
#
# Run ID: ca3 was successful after 4m1s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_8b51680a3d25697eb97ae6bfa3d79a96d69f65f1a90f468b04468d5ad9543b4b_d.txt
# ========================================================================================================================
# Login Succeeded
# :29Z Starting output-watcher...
# 2020-08-16T07:43:29Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Using default tag: latest
# latest: Pulling from azureml/azureml_87923348625dfb0a03e592d7635ea9b9
# fe703b657a32: Pulling fs layer
# f9df1fafd224: Pulling fs layer
# a645a4b887f9: Pulling fs layer
# 57db7fe0b522: Pulling fs layer
# 20b5fabe4f63: Pulling fs layer
# 22898513a7dc: Pulling fs layer
# b77f65fcd9d7: Pulling fs layer
# 132ebd5cd5ca: Pulling fs layer
# 01991399be72: Pulling fs layer
# 60c58ca14ef7: Pulling fs layer
# ca339bb1ce1b: Pulling fs layer
# 1d6fd176323e: Pulling fs layer
# 5a52fff882e8: Pulling fs layer
# 1bb76fdbdf7a: Pulling fs layer
# fa5da959a02e: Pulling fs layer
# 6ca23738494e: Pulling fs layer
# 76f0cb11988e: Pulling fs layer
# 57db7fe0b522: Waiting
# 20b5fabe4f63: Waiting
# 22898513a7dc: Waiting
# 5a52fff882e8: Waiting
# b77f65fcd9d7: Waiting
# 1bb76fdbdf7a: Waiting
# 132ebd5cd5ca: Waiting
# fa5da959a02e: Waiting
# 6ca23738494e: Waiting
# 01991399be72: Waiting
# 60c58ca14ef7: Waiting
# ca339bb1ce1b: Waiting
# 1d6fd176323e: Waiting
# 76f0cb11988e: Waiting
# a645a4b887f9: Verifying Checksum
# a645a4b887f9: Download complete
# f9df1fafd224: Verifying Checksum
# f9df1fafd224: Download complete
# 57db7fe0b522: Verifying Checksum
# 57db7fe0b522: Download complete
# fe703b657a32: Verifying Checksum
# fe703b657a32: Download complete
# 22898513a7dc: Verifying Checksum
# 22898513a7dc: Download complete
# 20b5fabe4f63: Verifying Checksum
# 20b5fabe4f63: Download complete
# b77f65fcd9d7: Verifying Checksum
# b77f65fcd9d7: Download complete
# 60c58ca14ef7: Verifying Checksum
# 60c58ca14ef7: Download complete
# ca339bb1ce1b: Verifying Checksum
# ca339bb1ce1b: Download complete
# 132ebd5cd5ca: Verifying Checksum
# 132ebd5cd5ca: Download complete
# 1d6fd176323e: Verifying Checksum
# 1d6fd176323e: Download complete
# 5a52fff882e8: Verifying Checksum
# 5a52fff882e8: Download complete
# fa5da959a02e: Verifying Checksum
# fa5da959a02e: Download complete
# 1bb76fdbdf7a: Verifying Checksum
# 1bb76fdbdf7a: Download complete
# 01991399be72: Verifying Checksum
# 01991399be72: Download complete
# 76f0cb11988e: Verifying Checksum
# 76f0cb11988e: Download complete
# fe703b657a32: Pull complete
# 6ca23738494e: Verifying Checksum
# 6ca23738494e: Download complete
# f9df1fafd224: Pull complete
# a645a4b887f9: Pull complete
# 57db7fe0b522: Pull complete
# 20b5fabe4f63: Pull complete
# 22898513a7dc: Pull complete
# b77f65fcd9d7: Pull complete
# 132ebd5cd5ca: Pull complete
# 01991399be72: Pull complete
# 60c58ca14ef7: Pull complete
# ca339bb1ce1b: Pull complete
# 1d6fd176323e: Pull complete
# 5a52fff882e8: Pull complete
# 1bb76fdbdf7a: Pull complete
# fa5da959a02e: Pull complete
# 6ca23738494e: Pull complete
# 76f0cb11988e: Pull complete
# Digest: sha256:9d01663ab714bbf374dab10858c1b3aefb80935e09ad9070aa83cb9dc1b3d4a4
# Status: Downloaded newer image for b1533106f06a49c8a9a7078ce1e0e1a3.azurecr.io/azureml/azureml_87923348625dfb0a03e592d7635ea9b9:latest
# f65d2c3df92b2b991970e9ea74ec6f2fc7e1864ba81e75fcaa85a448c2caa187
# 2020/08/16 07:45:31 setuptask.go:343: Instrumentation Key Is Empty Skipping App Insight Logger
# 2020/08/16 07:45:31 logger.go:293: Version: 3.0.01314.0006 Branch: .SourceBranch Commit: 0b1fee2
# 2020/08/16 07:45:31 utils.go:302: /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/08/16 07:45:31 logger.go:293: sshd runtime has already been installed in the container
# ssh-keygen: /azureml-envs/azureml_038971e8daecf4b45640448e5bd2c009/lib/libcrypto.so.1.0.0: no version information available (required by ssh-keygen)
# ssh-keygen: /azureml-envs/azureml_038971e8daecf4b45640448e5bd2c009/lib/libcrypto.so.1.0.0: no version information available (required by ssh-keygen)
# 2020/08/16 07:45:31 appinsightlogger.go:46: Logger is Nil nothing to close
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# [2020-08-16T07:45:52.588187] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['driver/amlbi_main.py', '--client_sdk_version', '1.9.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/55a549b7-5d3b-49b4-bdc4-1391d5152d90/mounts/workspaceblobstore/azureml/55a549b7-5d3b-49b4-bdc4-1391d5152d90/inferences', '--input_fds_0', 'diabetes_batch', '--input1', '/mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/55a549b7-5d3b-49b4-bdc4-1391d5152d90/mounts/workspaceblobstore/batch-data/'])
# Initialize DatasetContextManager.
# Starting the daemon thread to refresh tokens in background for process with pid = 137
# Set Dataset diabetes_batch's target path to /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/55a549b7-5d3b-49b4-bdc4-1391d5152d90/mounts/workspaceblobstore/azureml/55a549b7-5d3b-49b4-bdc4-1391d5152d90/8c9049b1-8bd1-4085-832b-05d0c9c2c05f
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.9.0 azureml-dataprep==2.0.6. Session id: 79cee36e-0352-4ba2-8e37-953faaa02ced.
# Processing 'diabetes_batch'
# Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'batch-data/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "2f10edc0-22f0-4809-b814-97675ad9f0b8",
#     "name": "batch-data",
#     "version": 1,
#     "description": "batch data",
#     "workspace": "Workspace.create(name='ms-learn-ml', subscription_id='375be063-544d-4b99-aed9-5a0e16b1f428', resource_group='ms-learn-ml')"
#   }
# }
# Mounted diabetes_batch to /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/55a549b7-5d3b-49b4-bdc4-1391d5152d90/mounts/workspaceblobstore/batch-data/
# Exit __enter__ of DatasetContextManager
# Entering Run History Context Manager.
# Current directory:  /mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/55a549b7-5d3b-49b4-bdc4-1391d5152d90/mounts/workspaceblobstore/azureml/55a549b7-5d3b-49b4-bdc4-1391d5152d90
# Preparing to call script [ driver/amlbi_main.py ] with arguments: ['--client_sdk_version', '1.9.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/55a549b7-5d3b-49b4-bdc4-1391d5152d90/mounts/workspaceblobstore/azureml/55a549b7-5d3b-49b4-bdc4-1391d5152d90/inferences', '--input_fds_0', 'diabetes_batch', '--input1', '/mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/55a549b7-5d3b-49b4-bdc4-1391d5152d90/mounts/workspaceblobstore/batch-data/']
# After variable expansion, calling script [ driver/amlbi_main.py ] with arguments: ['--client_sdk_version', '1.9.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/55a549b7-5d3b-49b4-bdc4-1391d5152d90/mounts/workspaceblobstore/azureml/55a549b7-5d3b-49b4-bdc4-1391d5152d90/inferences', '--input_fds_0', 'diabetes_batch', '--input1', '/mnt/batch/tasks/shared/LS_root/jobs/ms-learn-ml/azureml/55a549b7-5d3b-49b4-bdc4-1391d5152d90/mounts/workspaceblobstore/batch-data/']
#
# Script type = None
# Starting the daemon thread to refresh tokens in background for process with pid = 137
#
#
# The experiment completed successfully. Finalizing run...
# [2020-08-16T07:46:39.347975] TimeoutHandler __init__
# [2020-08-16T07:46:39.348060] TimeoutHandler __enter__
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 2 items cleaning up...
# Cleanup took 0.31703710556030273 seconds
# [2020-08-16T07:46:39.776621] TimeoutHandler __exit__
# Enter __exit__ of DatasetContextManager
# Exit __exit__ of DatasetContextManager
# 2020/08/16 07:46:41 logger.go:293: Process Exiting with Code:  0
#
# Streaming azureml-logs/75_job_post-tvmps_faf0a0bb1bd644ebd9f31d0db81d48fb5e818fca15e25a981c0a271e070ef5af_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-08-16T07:46:41.955740
# Starting job release. Current time:2020-08-16T07:46:42.965856
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 533
# [2020-08-16T07:46:42.986804] Entering context manager injector.
# Job release is complete. Current time:2020-08-16T07:46:43.630858
#
# Streaming azureml-logs/75_job_post-tvmps_8b51680a3d25697eb97ae6bfa3d79a96d69f65f1a90f468b04468d5ad9543b4b_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-08-16T07:46:42.331939
#
# StepRun(batch-score-diabetes) Execution Summary
# ================================================
# StepRun( batch-score-diabetes ) Status: Finished
# {'runId': '55a549b7-5d3b-49b4-bdc4-1391d5152d90', 'target': 'ms-learn-CCryan', 'status': 'Completed', 'startTimeUtc': '2020-08-16T07:43:19.563073Z', 'endTimeUtc': '2020-08-16T07:47:13.919896Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': 'e3bf463a-5291-4269-917b-4e1388b0f9d1', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '8a749328-b56a-420f-b4ec-90d3e0452437', 'azureml.pipelinerunid': 'd462eca3-a5e1-41ae-a27b-56261b3f03f4', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '2f10edc0-22f0-4809-b814-97675ad9f0b8'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_batch', 'mechanism': 'Mount', 'pathOnCompute': '8c9049b1-8bd1-4085-832b-05d0c9c2c05f'}}], 'runDefinition': {'script': 'driver/amlbi_main.py', 'scriptType': None, 'useAbsolutePath': False, 'arguments': ['--client_sdk_version', '1.9.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '$AZUREML_DATAREFERENCE_inferences', '--input_fds_0', 'diabetes_batch', '--input1', '$AZUREML_DATAREFERENCE_diabetes_batch_0'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'ms-learn-CCryan', 'dataReferences': {'diabetes_batch_0': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'batch-data/', 'pathOnCompute': None, 'overwrite': False}, 'inferences': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/55a549b7-5d3b-49b4-bdc4-1391d5152d90/inferences', 'pathOnCompute': 'diabetes/results', 'overwrite': False}}, 'data': {'diabetes_batch': {'dataLocation': {'dataset': {'id': '2f10edc0-22f0-4809-b814-97675ad9f0b8', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Mount', 'environmentVariableName': 'diabetes_batch', 'pathOnCompute': '8c9049b1-8bd1-4085-832b-05d0c9c2c05f', 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 2, 'environment': {'name': 'batch_environment', 'version': 'Autosave_2020-08-16T07:35:00Z_a241a71b', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['scikit-learn', 'azureml-defaults~=1.9.0', 'azureml-core~=1.9.0', 'azureml-dataprep[fuse]']}], 'name': 'azureml_038971e8daecf4b45640448e5bd2c009'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200423.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {' ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'd462eca3-a5e1-41ae-a27b-56261b3f03f4', 'status': 'Completed', 'startTimeUtc': '2020-08-16T07:32:52.544584Z', 'endTimeUtc': '2020-08-16T07:47:25.902027Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mslearnml9203005896.blob.core.windows.net/azureml/ExperimentRun/dcid.d462eca3-a5e1-41ae-a27b-56261b3f03f4/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=6r6Zy%2BoyMuuDdveoFPWvbslyIiWrjgs5A%2FymSDCGYto%3D&st=2020-08-16T07%3A23%3A24Z&se=2020-08-16T15%3A33%3A24Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mslearnml9203005896.blob.core.windows.net/azureml/ExperimentRun/dcid.d462eca3-a5e1-41ae-a27b-56261b3f03f4/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=JuCNaufqpjOTBflFjvZVt5DMZe145elMUm%2Bc0mWBIo8%3D&st=2020-08-16T07%3A23%3A24Z&se=2020-08-16T15%3A33%3A24Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mslearnml9203005896.blob.core.windows.net/azureml/ExperimentRun/dcid.d462eca3-a5e1-41ae-a27b-56261b3f03f4/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=JzygM22zCjf77A2Rn3maI23PmLjxopO6c1f0BYLBQnk%3D&st=2020-08-16T07%3A23%3A24Z&se=2020-08-16T15%3A33%3A24Z&sp=r'}}
# 'Finished'

# %% [markdown]
# When the pipeline has finished running, the resulting predictions will have been saved in the outputs of the experiment associated with the first (and only) step in the pipeline. You can retrieve it as follows:

# %%
import pandas as pd
import shutil

shutil.rmtree('diabetes-results', ignore_errors=True)

prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')


for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#       File  Prediction
# 0   27.csv           0
# 1   28.csv           0
# 2   29.csv           0
# 3    3.csv           1
# 4   30.csv           0
# 5   77.csv           0
# 6   78.csv           0
# 7   79.csv           1
# 8    8.csv           1
# 9   80.csv           0
# 10  36.csv           1
# 11  37.csv           1
# 12  38.csv           1
# 13  39.csv           0
# 14   4.csv           0
# 15  90.csv           0
# 16  91.csv           0
# 17  92.csv           0
# 18  93.csv           0
# 19  94.csv           1

# %% [markdown]
# ## Publish the Pipeline and use its REST Interface
#
# Now that you have a working pipeline for batch inferencing, you can publish it and use a REST endpoint to run it from an application.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name='Diabetes_Parallel_Batch_Pipeline', description='Batch scoring of diabetes data', version='1.0')

published_pipeline
# Out:
# Pipeline(Name: Diabetes_Parallel_Batch_Pipeline,
# Id: 4f4e90d2-6603-4a4d-afe7-8d2f5342d9f7,
# Status: Active,
# Endpoint: https://eastus.api.azureml.ms/pipelines/v1.0/subscriptions/375be063-544d-4b99-aed9-5a0e16b1f428/resourceGroups/ms-learn-ml/providers/Microsoft.MachineLearningServices/workspaces/ms-learn-ml/PipelineRuns/PipelineSubmit/4f4e90d2-6603-4a4d-afe7-8d2f5342d9f7)

# %% [markdown]
# Note that the published pipeline has an endpoint, which you can see in the Azure portal. You can also find it as a property of the published pipeline object:

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://eastus.api.azureml.ms/pipelines/v1.0/subscriptions/375be063-544d-4b99-aed9-5a0e16b1f428/resourceGroups/ms-learn-ml/providers/Microsoft.MachineLearningServices/workspaces/ms-learn-ml/PipelineRuns/PipelineSubmit/4f4e90d2-6603-4a4d-afe7-8d2f5342d9f7

# %% [markdown]
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. To test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:
#
# > **Note**: A real application would require a service principal with which to be authenticated.

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print('Authentication header ready.')
# Out:
# Authentication header ready.

# %% [markdown]
# Now we're ready to call the REST interface. The pipeline runs asynchronously, so we'll get an identifier back, which we can use to track the pipeline experiment as it runs:

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "Batch_Pipeline_via_REST"})
run_id = response.json()["Id"]
run_id
# Out:
# 'cc7ae638-bf8f-456c-902c-87193b78cb45'

# %% [markdown]
# Since we have the run ID, we can view the experiment as it runs:

# %%
from azureml.pipeline.core.run import PipelineRun

published_pipeline_run = PipelineRun(ws.experiments["Batch_Pipeline_via_REST"], run_id)
print('Running pipeline...')
published_pipeline_run.wait_for_completion(show_output=True)
# Out:
# Running pipeline...
# PipelineRunId: cc7ae638-bf8f-456c-902c-87193b78cb45
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/Batch_Pipeline_via_REST/runs/cc7ae638-bf8f-456c-902c-87193b78cb45?wsid=/subscriptions/375be063-544d-4b99-aed9-5a0e16b1f428/resourcegroups/ms-learn-ml/workspaces/ms-learn-ml
# PipelineRun Status: Running
#
#
# StepRunId: d3d2ec33-4653-45ea-95f4-bbc39ccd6de2
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/Batch_Pipeline_via_REST/runs/d3d2ec33-4653-45ea-95f4-bbc39ccd6de2?wsid=/subscriptions/375be063-544d-4b99-aed9-5a0e16b1f428/resourcegroups/ms-learn-ml/workspaces/ms-learn-ml
# StepRun( batch-score-diabetes ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_81f9259acb83b217e325aff820aa90a1bd9200884475f902a89f781c6919fb09_d.txt
# ========================================================================================================================
# Login Succeeded
# :51Z Starting output-watcher...
# 2020-08-16T07:58:51Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Using default tag: latest
# latest: Pulling from azureml/azureml_87923348625dfb0a03e592d7635ea9b9
# fe703b657a32: Pulling fs layer
# f9df1fafd224: Pulling fs layer
# a645a4b887f9: Pulling fs layer
# 57db7fe0b522: Pulling fs layer
# 20b5fabe4f63: Pulling fs layer
# 22898513a7dc: Pulling fs layer
# b77f65fcd9d7: Pulling fs layer
# 132ebd5cd5ca: Pulling fs layer
# 01991399be72: Pulling fs layer
# 60c58ca14ef7: Pulling fs layer
# ca339bb1ce1b: Pulling fs layer
# 1d6fd176323e: Pulling fs layer
# 5a52fff882e8: Pulling fs layer
# 1bb76fdbdf7a: Pulling fs layer
# fa5da959a02e: Pulling fs layer
# 6ca23738494e: Pulling fs layer
# 76f0cb11988e: Pulling fs layer
# 60c58ca14ef7: Waiting
# ca339bb1ce1b: Waiting
# 1d6fd176323e: Waiting
# 5a52fff882e8: Waiting
# 1bb76fdbdf7a: Waiting
# fa5da959a02e: Waiting
# 6ca23738494e: Waiting
# 76f0cb11988e: Waiting
# 22898513a7dc: Waiting
# b77f65fcd9d7: Waiting
# 132ebd5cd5ca: Waiting
# 01991399be72: Waiting
# 57db7fe0b522: Waiting
# 20b5fabe4f63: Waiting
# f9df1fafd224: Verifying Checksum
# f9df1fafd224: Download complete
# a645a4b887f9: Verifying Checksum
# a645a4b887f9: Download complete
# 57db7fe0b522: Verifying Checksum
# 57db7fe0b522: Download complete
# fe703b657a32: Verifying Checksum
# fe703b657a32: Download complete
# 22898513a7dc: Verifying Checksum
# 22898513a7dc: Download complete
# b77f65fcd9d7: Verifying Checksum
# b77f65fcd9d7: Download complete
# 20b5fabe4f63: Verifying Checksum
# 20b5fabe4f63: Download complete
# 60c58ca14ef7: Verifying Checksum
# 60c58ca14ef7: Download complete
# ca339bb1ce1b: Verifying Checksum
# ca339bb1ce1b: Download complete
# 132ebd5cd5ca: Verifying Checksum
# 132ebd5cd5ca: Download complete
# 1d6fd176323e: Verifying Checksum
# 1d6fd176323e: Download complete
# 5a52fff882e8: Verifying Checksum
# 5a52fff882e8: Download complete
# 1bb76fdbdf7a: Verifying Checksum
# 1bb76fdbdf7a: Download complete
# fa5da959a02e: Verifying Checksum
# fa5da959a02e: Download complete
# 76f0cb11988e: Verifying Checksum
# 76f0cb11988e: Download complete
# 01991399be72: Verifying Checksum
# 01991399be72: Download complete
# fe703b657a32: Pull complete
# f9df1fafd224: Pull complete
# a645a4b887f9: Pull complete
# 6ca23738494e: Verifying Checksum
# 6ca23738494e: Download complete

# %% [markdown]
# As before, the results are in the output of the first pipeline step:

# %%
import pandas as pd
import shutil

shutil.rmtree("diabetes-results", ignore_errors=True)

prediction_run = next(published_pipeline_run.get_children())
prediction_output = prediction_run.get_output_data("inferences")
prediction_output.download(local_path="diabetes-results")


for root, dirs, files in os.walk("diabetes-results"):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)

# %% [markdown]
# Now you have a pipeline that can be used to batch process daily patient data.
#
# **More Information**: For more details about using pipelines for batch inferencing, see the [How to Run Batch Predictions](https://docs.microsoft.com/azure/machine-learning/how-to-run-batch-predictions) in the Azure Machine Learning documentation.
